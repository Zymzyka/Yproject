# %% [markdown]
# **Привет, Александр!** 👋
#
# Меня зовут Артем Пиляй. Я буду проверять твой проект. В рамках корпоративной этики мы общаемся на «ты». Но если лучше на «Вы», то нужно обозначить это сразу.
#
# В тетрадке есть комментарии к проекту, они будут в отдельных ячейках Markdown.
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Такой комментарий **нужно исправить** обязательно, он критически влияет на удачное выполнение проекта.
#
# </div>
#
# <div class="alert alert-warning">
#
# **Артём:** 👉 Если таких комментариев в проекте **не больше трех**, то проект будет принят. Но есть два исключения, при которых я приму проект с любым количеством желтых комментариев, красные нужно исправить все:
#
# * если у тебя дедлайн, тогда оставь в начале 👆 проекта комментарий «Дедлайн, специальность (DA/DS/DA+/DS+), и номер когорты»;
# * если ты считаешь, что для успешного трудоустройства и для успешной работы в команде тебе это не нужно, тогда оставь в начале проекта комментарий «Не нужно».
# </div>
#
# <div class="alert alert-success">
#
# **Артём:** 👍 А это **самый главный комментарий**, значит все сделано хорошо. 😉
#
# </div>
#
# <div class="alert alert-info">
#
# **Артём:** ✍️ В таких комментариях я оставляю подсказки как сделать **твой проект ещё лучше**.
#
# </div>
#
# ---
#
# **Распространенные ошибки**
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Не перемещай и не удаляй мои комментарии. Лучше, чтобы твои ответы на мои комментарии шли по очереди, как сообщения в мессенджере. Это ускорит проверку.
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).
#
# </div>
#
# <div class="alert alert-info">
#
# **Артём:** ✍️ Кстати, смотри как можно сделать, чтобы датасет грузился и локально, и в JupyterHub:
#
# ```py
# try:
#     df = pd.read_csv('C:/Users/Student/Desktop/dataset.csv')
# except:
#     df = pd.read_csv('/datasets/dataset.csv')
# ```
#
# Используя эту конструкцию в будущих проектах, ты будешь спокойно отправлять проект на проверку зная, что он будет работать.
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Проект должен быть структурирован. Где названия разделов и подразделов будут записаны в ячейках Markdown.
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Если с твоим проектом будет знакомиться другой человек, например рекрутер или старший дата специалист, в нем должны быть описаны поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.
#
# </div>
#
# <div class="alert alert-warning">
#
# **Артём:** 👉 Длинный код и комментарии нужно переносить на новую строку. Согласись, коллеги не оценят, если им придется тратить время на пролистывание ячеек. Согласно международному стандарту [PEP8](https://www.python.org/dev/peps/pep-0008/) длина строки не должна превышать 79 символов.
# Вот как можно перенести код на новую строку:
#
# ```py
# # Переносить можно код внутри скобки
# example = (2 *
#            2)
# ```
# Конечно, я не считаю сколько символов в строке, главное, чтобы код или комментарий не ушел за пределы ячейки (зависит от разрешения экрана). Если ушел, то это желтый комментарий для каждой нечитаемой ячейки.
#
# </div>
#
# <div class="alert alert-warning">
#
# **Артём:** 👉 Тимлид, старший дата специалист или ревьюер ценят твое и своё время, подсвечивай свои комментарии в ячейках Markdown. Шаблон я тебе оставил ниже. Подробнее про синтаксис Markdown, с примерами, можно почитать [здесь](https://paulradzkov.com/2014/markdown_cheatsheet/?).
#
# </div>
#
# <div class="alert alert-success">
#
# **Артём:** 👍 Буду рад, если воспользуешься моими советами. Они тебе помогут при трудоустройстве и при работе в команде. Если в ходе проведения исследования возникнут вопросы, не стесняйся задавай. 🙂
# </div>
#
# <div class="alert alert-info">
#
# **Артём:** 🏁 [Итоги ревью здесь](#results)
# </div>
#
#
# **Поехали!** 🚀 👨‍🚀
# <a id="start"></a>

# %% [markdown]
# <div class="alert alert-info">
# Я для переноса кода использую \ возможно, где то упустил, большой проект..
# <div>

# %% [markdown]
# <div style="background-color:black; color:#ffffff; text-align:center; padding:2%">
#
# **Имя:** Это шаблон для тебя. Такой комментарий можно быстро найти.

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Добавь структуру проекта как в ТЗ.
#
# ```
# ## Шаг 1. Откройте файл с данными и изучите общую информацию
# ## Шаг 2. Подготовьте данные
# ### Замените названия столбцов (приведите к нижнему регистру)
# ### Преобразуйте данные в нужные типы
# ### Опишите, в каких столбцах заменили тип данных и почему
# ### Обработайте пропуски при необходимости
# ### Объясните, почему заполнили пропуски определённым образом или почему не стали это делать
# ### Опишите причины, которые могли привести к пропускам
# ### Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей, Отдельно разберите это значение и опишите, как его обработать
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец
# ## Шаг 3. Проведите исследовательский анализ данных
# ### Посмотрите, сколько игр выпускалось в разные годы
# ### Важны ли данные за все периоды?
# ### Посмотрите, как менялись продажи по платформам.
# ### Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.
# ### За какой характерный срок появляются новые и исчезают старые платформы?
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. **Не учитывайте в работе данные за предыдущие годы.**
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# ### Соотнесите выводы с продажами игр на других платформах.
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
# ## Шаг 4. Составьте портрет пользователя каждого региона
# ### Определите для пользователя каждого региона (NA, EU, JP):
# ### Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# ### Самые популярные жанры (топ-5). Поясните разницу.
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?
# ## 📊 Шаг 5. Проверьте гипотезы
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.
# ### 📊 Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# ### 📊 Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# ## Шаг 6. Напишите общий вывод
# ```
#
# </div>
# <div class="alert alert-info">
#
# **Артём:** ✍️ Пример, как это делать, я тебе оставил в пятом шаге в тетрадке.
# Посмотри в меню **Content** слева. Чтобы не перепутать твои и мои ячейки, я добавил эмоджи 📊.
# Теперь он структурирован, тебе так нужно сделать в остальном проекте.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Заполнил Contents - сложно заполнять уже  в готовом проекте. Но я для себя сделал большой урок по структуре.
# Целое доп ислледование хорошо. Но всегда есть на это время :)
# <div>

# %% [markdown]
# <div class="alert alert-info">
# Пришлос правда разобраться как локально на юпитере сделать меню контент! Я смог :)
# <div>

# %% [markdown]
# # Описание проекта
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# # Задачи проекта
#
# Шаг 2. Подготовьте данные
#
#     Замените названия столбцов (приведите к нижнему регистру);
#     Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
#     Обработайте пропуски при необходимости:
#
#     Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#     Опишите причины, которые могли привести к пропускам;
#         Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
#     Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# Шаг 3. Проведите исследовательский анализ данных
#
#     Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#     Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
#     Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#     Не учитывайте в работе данные за предыдущие годы.
#     Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#     Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#     Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#     Соотнесите выводы с продажами игр на других платформах.
#     Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Шаг 4. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
#
#     Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#     Самые популярные жанры (топ-5). Поясните разницу.
#     Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# Шаг 5. Проверьте гипотезы
#
#     Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#     Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
#
#     Как вы сформулировали нулевую и альтернативную гипотезы;
#     Какой критерий применили для проверки гипотез и почему.
#
# Шаг 6. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
# Описание данных
#
#     Name — название игры
#     Platform — платформа
#     Year_of_Release — год выпуска
#     Genre — жанр игры
#     NA_sales — продажи в Северной Америке (миллионы проданных копий)
#     EU_sales — продажи в Европе (миллионы проданных копий)
#     JP_sales — продажи в Японии (миллионы проданных копий)
#     Other_sales — продажи в других странах (миллионы проданных копий)
#     Critic_Score — оценка критиков (максимум 100)
#     User_Score — оценка пользователей (максимум 10)
#     Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Отлично, что есть описание проекта и столбцов датасета.
# </div>

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию

# %%
#Запускаем библиотеку пандас для работы с таблицами.
import pandas as pd
#Запускает бибилиотеку matplotlib для работы с plot 
import matplotlib.pyplot as plt
#Запускаем библиотеку numpy для работы с массивами
import numpy as np
#Импортируем метод для таблиц
import seaborn as sns
#Запускаем билиотеку для проверки гипотез
from scipy import stats as st

# %%
#открыли датасет
try:
    df = pd.read_csv('C:/Users/hulyg/games.csv')
except:
    df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Правильно, что импортируешь библиотеки в начале проекта, а так же разделяешь загрузку библиотек, датасета и рабочий код.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Сделал путь, как ты посоветовал.
# <div>

# %%
#посмотрели информацию о дата сете
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
#Вывели первые 20 строк дата сета 
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# В df.describe() видим, что значения min и 25%  в продажах по регионам равны 0.0, в min в целом все выглядит нормально.
# Так как min = 1980 год. Продажи не фиксировались на агрегаторах а компании которые тогда существовали закрылись (примичание Atari, теперь издатель)
# Значение 25% относится 2003 год , значения тоже равны 0.0, надо детально посмотреть.
#
# В значение max с годом 2016 в NA_sales есть показатель в 41.36 миллиона. Рынок северной америки самый крупный. для нее такой показатель по очень популярной игре нормально.
#
# В целом все значения укладываются в норму мира геймдева.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец.
#
# </div>

# %%
#Посмотрели квартили,средние максимальные и минимальные значения и количество строк 
df.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
#Просмотрели сколько пропущенных строк и отсортировали по убыванию
df.isna().sum().sort_values()
# Out:
# Platform              0
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Name                  2
# Genre                 2
# Year_of_Release     269
# User_Score         6701
# Rating             6766
# Critic_Score       8578
# dtype: int64

# %%
#Проверили на явные дубликаты
df.duplicated().sum()
# Out:
# 0

# %%
#построили гистограммы на сырые данные
df.hist(figsize=(10,15));

# %% [markdown]
# <div class="alert alert-info">
#
# **Артём:** ✍️ Чтобы не выводить `<...>` можно поставить в конце строки `;`.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Cпасибо, убрал!
# </div>

# %% [markdown]
# # Общий  вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Подключили библиотеки пандас, матлиб, нампи, сеаборн для работы с датасетом.
#
# Открыли датасет и проверили
#
# Открыли датасет в df.describe()  - сделали пару замечаний разберем в предобработке данных
#
# Проверили на явные дубликаты, не обнаружено.
#
# Нашли пропущенные значения в колонках и их количество
#
# Построили гистограммы на сырые данные
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %% [markdown]
# ## Шаг 2. Подготовьте данные

# %% [markdown]
# ### Замените названия столбцов (приведите к нижнему регистру)

# %%
#Привели к нижнему регистру названия игр 
df['Name'] = df['Name'].str.lower()

# %%
#Жанры привели к нижнему регистру
df['Genre'] = df['Genre'].str.lower()

# %%
#Платформы привели к нижнему регистру
df['Platform'] = df['Platform'].str.lower()

# %%
#Убедились что нету нету явных дубликатов
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-info">
#  Привели три столбца name, genre, platform к единому регистру, дополнительно посмотрели на дубликаты, не обнаружено.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Верно.
#
# </div>

# %% [markdown]
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец

# %%
#Считаем суммарные продажи по всем регионам
df['all_region_sales'] = df['NA_sales'] + df['EU_sales'] + df['JP_sales'] + df['Other_sales']

# %% [markdown]
# <div class="alert alert-info">
#
# **Артём:** ✍️ Есть еще такой способ:
#
# ```py
# df[['column_1','column_2','column_3', 'column_4']].sum(axis = 1)
# ```
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Круто! Ребята спрашивали. как можно сложить красиво! Вот и способ :)
# <dib>

# %%
#Все колонки привели к нижнему регистру
df = df.rename(str.lower, axis='columns')

# %% [markdown]
# <div class="alert alert-info">
#
# **Артём:** ✍️ Есть способ проще:
#
# ```py
# df.columns = df.columns.str.lower()
# ```
#
# </div>

# %%
#Проверяем
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii           2006.0        sports     41.36
# 1         super mario bros.      nes           1985.0      platform     29.08
# 2            mario kart wii      wii           2008.0        racing     15.68
# 3         wii sports resort      wii           2009.0        sports     15.61
# 4  pokemon red/pokemon blue       gb           1996.0  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating  \
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
#
#    all_region_sales
# 0             82.54
# 1             40.24
# 2             35.52
# ...

# %% [markdown]
# <div class="alert alert-info">
#
# **Артём:** ✍️ В методах `head()` и `tail()` 5 можно не писать, так как она идет по умолчанию.
#
# </div>

# %% [markdown]
# # 1  Предобработка name и genre

# %% [markdown]
# <div class="alert alert-block alert-info">
# Поиск пропусков в genre и name , думаю что они связанны, всего 2 пропуска в каждом столбце.
# <div>

# %%
#Cмотрим уникальные значения игровых жанров 
df['genre'].unique()
# Out:
# array(['sports', 'platform', 'racing', 'role-playing', 'puzzle', 'misc',
#        'shooter', 'simulation', 'action', 'fighting', 'adventure',
#        'strategy', nan], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-info">
# Заменить в столбце genre  пропуски NaN на переменную 1 и посмотрим какие две игры мы найдем.
# <div>

# %%
#Меняем пропуски на 1, чтобы сделать срез.
df['genre'] = df['genre'].fillna('1')
df['genre'].unique()
# Out:
# array(['sports', 'platform', 'racing', 'role-playing', 'puzzle', 'misc',
#        'shooter', 'simulation', 'action', 'fighting', 'adventure',
#        'strategy', '1'], dtype=object)

# %%
#Делаем срез по 1
df_pass = df.query('genre =="1"')
df_pass
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      gen           1993.0     1      1.78      0.53      0.00
# 14244  NaN      gen           1993.0     1      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating  all_region_sales
# 659           0.08           NaN        NaN    NaN              2.39
# 14244         0.00           NaN        NaN    NaN              0.03

# %%
#Удаляем по индексу
df.drop(labels = [659,14244],axis = 0, inplace = True)

# %% [markdown]
# <div class="alert alert-warning">
#
# **Артём:** 👉 Так лучше не делать. На случай изменения датасета, лучше работать с переменными.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Заменил на переменную, можем создать любую, и добавить описание? Чтобы мы не забыли или кто-то другой понял.
# <dib>

# %%
#Проверили
df['genre'].unique()
# Out:
# array(['sports', 'platform', 'racing', 'role-playing', 'puzzle', 'misc',
#        'shooter', 'simulation', 'action', 'fighting', 'adventure',
#        'strategy'], dtype=object)

# %% [markdown]
# # Вывод Предобработка name и genre

# %% [markdown]
# <div class="alert alert-block alert-info">
# Выяснили что пропущенные значения в имени и жанре. Это две игры выходившие на сега генезис. в 1993 году. Выяснить имя игры и жанра не предстовляетяс возможным. удалим и забудем :)
# <div>

# %% [markdown]
# # 2  Предобработка year_of_release

# %%
#Смотрим уникальные значених по годам. нет ли пропущенных годов полностью
df['year_of_release'].sort_values().unique()
# Out:
# array([1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988.,
#        1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997.,
#        1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016.,   nan])

# %%
#Удалил пропуски и проверили 
df = df.dropna(subset=['year_of_release'])
df['year_of_release'].sort_values().unique()
# Out:
# array([1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988.,
#        1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997.,
#        1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016.])

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Согласен.
#
# </div>

# %%
#Меням значения nan года на 'undefined' для изменения типа данных
#df['year_of_release'] = df['year_of_release'].fillna(0)

# %% [markdown]
# <div class="alert alert-info">
#
# **Артём:** ✍️ Можно не комментировать весь код, а просто менять тип ячейки с `Code` на `Raw NBCovert`.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Очень крутая функция, спасибо! Воспользуюсь!
# <div>

# %%
df['year_of_release'] = df['year_of_release'].astype('int32')

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Правильно.
#
# </div>

# %%
#Проверяем
df.dtypes
# Out:
# name                 object
# platform             object
# year_of_release       int32
# genre                object
# na_sales            float64
# eu_sales            float64
# jp_sales            float64
# other_sales         float64
# critic_score        float64
# user_score           object
# rating               object
# all_region_sales    float64
# dtype: object

# %% [raw]
# #Делаем срез по пропущенным значениям в годах
# #pass_year  = df.query('year_of_release == 0')
# #pass_year.head(5)

# %% [raw]
# #Смотрим сколько было пропущенно лет в играх по платформам. Чтобы не было аномальных значений.
# #pass_year.groupby(['platform','year_of_release']).agg({'name' : 'count'}).sort_values(by='name',ascending=False)

# %% [raw]
# #Для сравнения выводим все релизы на все платформы
# #df.groupby('platform').agg({'name' : 'count'}).sort_values(ascending=False, by='platform') \
# #.sort_values(by='name',ascending=False)

# %% [raw]
# #Строим два графика пропущенные года  по платформе и всего игр на платформе
# #pass_year.groupby('platform').agg({'name' : 'count'}).sort_values(by='name') \
# #.plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
# #plt.ylabel('Платформа')
# #plt.xlabel('Количество')
#
# #df.groupby('platform').agg({'name' : 'count'}).sort_values(by='name') \
# #.plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
# #plt.ylabel('Платформа')
# #plt.xlabel('Количество')

# %% [markdown]
# # Вывод предобработка year_of_release

# %% [markdown]
# <div class="alert alert-block alert-info">
# Получили больше всего пропусков на платформе wii и ps2 по 34 штуки чуть меньше но достаточно много на xbox 360 и ds по 30 шт. сравнили с количеством выпущенных игр за все время жизни платформы.
# На платформе ps2 и ds вышло рекордное количество игр больше 2000 тысяч, а пропусков всего 34 и 30 шт.
#
# На платформе pcfx и gg - выходило по одной +и мы не знаем года выхода. Такие данные не предоствляют ценности.
#
# Удалим пропуски чтобы они нам не мешали в дальнейшем, их не много всего 269 штук. После удаления пропусков все года у нас сохраняются в датасете.
# <div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Иследование задокументирую
# <div>

# %% [markdown]
#  # 3 Предобработка rating

# %% [markdown]
# <div class="alert alert-block alert-info">
# Сделаем срез от 1994 года и ниже. ESBR начала свою работу 16 сентября 1994 года.
# Посмотрим сколько пропусков может быть ниже 1994 года.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец.
#
# </div>

# %%
#Делаем срез по 1994 году и ниже , в 1994 году появилась ESBR в америке
year_1994 = df.loc[df['year_of_release'] <= 1994]
year_1994.head(5)
# Out:
#                  name platform  year_of_release     genre  na_sales  eu_sales  \
# 1   super mario bros.      nes             1985  platform     29.08      3.58
# 5              tetris       gb             1989    puzzle     23.20      2.26
# 9           duck hunt      nes             1984   shooter     26.93      0.63
# 18  super mario world     snes             1990  platform     12.78      3.75
# 21   super mario land       gb             1989  platform     10.83      2.71
#
#     jp_sales  other_sales  critic_score user_score rating  all_region_sales
# 1       6.81         0.77           NaN        NaN    NaN             40.24
# 5       4.22         0.58           NaN        NaN    NaN             30.26
# 9       0.28         0.47           NaN        NaN    NaN             28.31
# 18      3.54         0.55           NaN        NaN    NaN             20.62
# 21      4.18         0.42           NaN        NaN    NaN             18.14

# %%
#Количество всех игр вышедших с 1980 до 1994
len(year_1994['name'])
# Out:
# 486

# %%
#Смотрим пропущенные значения от 1994 года до 1980  483. 
year_1994.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score        482
# user_score          482
# rating              481
# all_region_sales      0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# Получили 483 значения игр без рейтинга количество всех игр у нас 488, значит что почти все игры не имели никакую оценку по возрасту до 1994 года.
# <div>

# %%
#Уникальные значения рейтинагов ESBR
df['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
#Делаем значения удобного вида, для восприятия
def rating_name (row):
    try:
        if 'E10' in row:
            return 'от 10 лет'
        elif 'E' in row or 'K-A' in row:
            return 'Любой возраст'
        elif 'E10+' in row:
            return 'от 10 лет'
        elif 'T' in row:
            return 'От 12 лет'
        elif 'M' in row :
            return 'От 17 лет'
        elif 'EC' in row:
            return 'Раннее детство'
        elif 'RP' in row:
            return 'Ожидается рейтинг, примерно 17+'
        elif 'AO' in row:
            return 'Только для взрослых'
    except:
        return 'нет рейтинга'

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец, удобно. И объединил правильно.
#
# </div>

# %%
#Сделали новую колонку со значениями отсортированными
df['rating_name'] = df['rating'].apply(rating_name)
df['rating_name'].unique()
# Out:
# array(['Любой возраст', 'нет рейтинга', 'От 17 лет', 'От 12 лет',
#        'от 10 лет', 'Только для взрослых',
#        'Ожидается рейтинг, примерно 17+'], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-info">
# Сделали столбец rating_name с более простым понимаем классификации рейтинга, также были обнаружены дубликаты это рейтинг E и K-A, K-А cо временем упрозднили и теперь все игры маркируются рейтингом E , было принято решение эти рейтинги в таблице обьединить.
# <div>

# %%
#Вывели датасэт и проверили, все огонь.
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii             2006        sports     41.36
# 1         super mario bros.      nes             1985      platform     29.08
# 2            mario kart wii      wii             2008        racing     15.68
# 3         wii sports resort      wii             2009        sports     15.61
# 4  pokemon red/pokemon blue       gb             1996  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating  \
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
#
#    all_region_sales    rating_name
# 0             82.54  Любой возраст
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Все огонь. 😁
#
# </div>

# %%
# Посмотрели сколько каких значений в рейтинге
df['rating_name'].value_counts()
# Out:
# нет рейтинга                       6676
# Любой возраст                      3932
# От 12 лет                          2905
# От 17 лет                          1536
# от 10 лет                          1393
# Только для взрослых                   1
# Ожидается рейтинг, примерно 17+       1
# Name: rating_name, dtype: int64

# %%
#Рассмотрим все игры без рейтинга
nope_rating = df.query('rating_name == "нет рейтинга"')
nope_rating_year = nope_rating.pivot_table(index='year_of_release', values='name', aggfunc='count')
nope_rating_year
# Out:
#                  name
# year_of_release
# 1980                9
# 1981               46
# 1982               36
# 1983               17
# 1984               14
# 1985               13
# 1986               21
# 1987               16
# 1988               14
# 1989               17
# 1990               16
# 1991               41
# 1992               41
# 1993               60
# 1994              120
# 1995              219
# 1996              256
# 1997              270
# 1998              347
# 1999              296
# 2000              202
# 2001              143
# 2002              174
# 2003              162
# 2004              164
# 2005              233
# 2006              328
# 2007              376
# 2008              446
# 2009              415
# 2010              456
# 2011              433
# 2012              298
# 2013              228
# 2014              236
# 2015              291
# 2016              222

# %%
#игры без рейтинга по платформам
nope_rating_year2 = nope_rating.pivot_table(index='platform', values='rating_name', aggfunc='count') \
.sort_values(by='rating_name')
nope_rating_year2
# Out:
#           rating_name
# platform
# gg                  1
# pcfx                1
# tg16                2
# 3do                 3
# ws                  6
# scd                 6
# ng                 12
# gen                27
# dc                 38
# wiiu               42
# xone               61
# gc                 85
# xb                 89
# gb                 97
# nes                98
# 2600              116
# ps4               137
# sat               173
# pc                200
# x360              202
# snes              239
# psv               279
# 3ds               289
# gba               297
# wii               309
# n64               316
# ps3               371
# psp               657
# ps2               671
# ds                866
# ps                986

# %%
#График выходших всех игр по годам
df.pivot_table(index='year_of_release', values='name', aggfunc='count').sort_values(by='year_of_release') \
.plot(grid=True, kind='barh', figsize=(5,10), fontsize=10)
plt.ylabel('Год релиза')
plt.xlabel('количество игр')
# Out:
# Text(0.5, 0, 'количество игр')

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Отсортируй по годам.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# У меня изначально была сортировка по годам.
#
# Сортировка по годам нам дает понимание изменеий и того как менялась картина выхода игр.
# Согласен так лучше!
#
# <div>

# %%
#График игр без рейтинга
nope_rating_year.sort_values(by='year_of_release') \
.plot(grid=True, kind='barh', figsize=(5,10), fontsize=10)
plt.ylabel('Год релиза')
plt.xlabel('нет рейтинга')
# Out:
# Text(0.5, 0, 'нет рейтинга')

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Отсортируй по годам.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Поправил, общая идея как и выше я пописал.
# <div>

# %% [markdown]
# # Вывод предобрабодка rating

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# -Мы выяснили, что до 1994 года. Играм не ставили никаких рейтингов.
# После 1994 года идет резкий скачет выпуск игр.
#
# - На графике видно, что самое большое количество игр без рейтинга это 2010,2008,2011.
#     Так же на графике релизов видно что самое большое количество игр выходило в 2008, 2009 , 2010.
#
# -В нашем датасете почти нету игр с рейтингом только 'для взрослых' - высокий рейтинг мешает продажам, издатели игр всегда предпочитают рейтинг  "От 17 лет" .
#
# -Так же у нас 4 региона. NA, EU, JP и Другие. все регионы имеют свои особенности рейтинговой системы.
# в EU это PEGI  она основана в 2003 году, в Японском регионе свои правила.
#
# -Вывод значения рейтинга не предстовляются возможным заполнить, если его не проставила профильная компания.
# Если нам надо будет работать с данными будем использовать новый созданый столбец rating_name
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %% [markdown]
# #  4 Предобработка user_score

# %% [markdown]
# <div class="alert alert-block alert-info">
# Значение TDB - означает не хватает данных для выставление рейтинга, условие сайта Metacritic или OpenCritic для выставление средней оценки,надо чтобы ее оценили пользователи 10 раз.
# Если меньше, то выставляет значение TDB. Ждет оценки.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец.
#
# </div>

# %%
#Посчитали проценты TDB в колонке юзер скорр
df['user_score'].value_counts(normalize=True) \
.sort_values(ascending=False).head(10)*100
# Out:
# tbd    24.148796
# 7.8     3.272690
# 8       2.896636
# 8.2     2.805163
# 8.3     2.561236
# 7.5     2.530745
# 8.5     2.510418
# 7.9     2.500254
# 8.1     2.408781
# 7.7     2.398618
# Name: user_score, dtype: float64

# %%
#Количество пропусков в колонке скорр
df['user_score'].isna().sum()
# Out:
# 6605

# %%
#Заменили значение nan в юзер скоре
#Cделали срез по tbd
df['user_score'] = df['user_score'].fillna(0)
df_score = df.query('user_score == 0')
df_score.head()
# Out:
#                         name platform  year_of_release         genre  \
# 1          super mario bros.      nes             1985      platform
# 4   pokemon red/pokemon blue       gb             1996  role-playing
# 5                     tetris       gb             1989        puzzle
# 9                  duck hunt      nes             1984       shooter
# 10                nintendogs       ds             2005    simulation
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating  \
# 1      29.08      3.58      6.81         0.77           NaN          0    NaN
# 4      11.27      8.89     10.22         1.00           NaN          0    NaN
# 5      23.20      2.26      4.22         0.58           NaN          0    NaN
# 9      26.93      0.63      0.28         0.47           NaN          0    NaN
# 10      9.05     10.95      1.93         2.74           NaN          0    NaN
#
#     all_region_sales   rating_name
# 1              40.24  нет рейтинга
# ...

# %%
#Cчитаем что TBD равно нет оценки 
df['user_score'] = df['user_score'].replace('tbd', 0)

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Правильно.
#
# </div>

# %%
#Проверяем
df['user_score'].unique()
# Out:
# array(['8', 0, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
#Меняем тип данных с обьекта на float64
df['user_score'] = df['user_score'].astype('float')

# %%
#Сводная таблица в какие года сколько было игр с пропущенным пользовательским оценками
df_score.pivot_table(index='year_of_release' , values='user_score', aggfunc='count').head(16)
# Out:
#                  user_score
# year_of_release
# 1980                      9
# 1981                     46
# 1982                     36
# 1983                     17
# 1984                     14
# 1985                     13
# 1986                     21
# 1987                     16
# 1988                     14
# 1989                     17
# 1990                     16
# 1991                     41
# 1992                     42
# 1993                     60
# 1994                    120
# 1995                    219

# %%
#Сколько всего вышло игр на платформах
df.pivot_table(index='year_of_release', values='name', aggfunc='count').head(16)
# Out:
#                  name
# year_of_release
# 1980                9
# 1981               46
# 1982               36
# 1983               17
# 1984               14
# 1985               14
# 1986               21
# 1987               16
# 1988               15
# 1989               17
# 1990               16
# 1991               41
# 1992               43
# 1993               60
# 1994              121
# 1995              219

# %% [markdown]
# <div class="alert alert-block alert-info">
# На двух графиках выше видно что данные почти одинаковые, игры без оценки пользователя(TBD) и количество всего игр вышедных в эти года.
# Причина проста. отсутсвие интернета, популярность журналов про игры. оценки были локальным в компаниях людей.
# Данную зависимость видно идеально.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %%
# График с пропущенными значениями пользовательских оценок
df_score.pivot_table(index='year_of_release' , values='user_score', aggfunc='count').sort_values(by='year_of_release') \
.plot(grid=True, kind='barh', figsize=(5,10), fontsize=10)
# Out:
# <AxesSubplot:ylabel='year_of_release'>

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Отсортируй по годам.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Осортировал
# <div>

# %%
#Количество релизов по годам
df.pivot_table(index='year_of_release', values='name', aggfunc='count') \
.sort_values(by='year_of_release') \
.plot(grid=True, kind='barh', figsize=(5,10), fontsize=10)
# Out:
# <AxesSubplot:ylabel='year_of_release'>

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Отсортируй по годам.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Осортировал
# <div>

# %% [markdown]
# # Вывод Предобработка user_score

# %% [markdown]
# <div class="alert alert-block alert-info">
# Выяснили зависимость от количества релизов игр в год на пользовательские оценки, чем больше релизов, тем меньше пользователи успевают поиграть в игры и оценить их , растет разнообразие игр при примерно одной базе геймеров. Возможно часть пользолвателей не заинтересованы в "пользовательской оценке" и сами не осталяют их, их больше интеерсует оценки критиков( профессиональных журналистов игровой индустрии)
#
# Значения было решено заполнить TBD, так как пользователь может пройти игру в любое удобное ему время и решить оставить оценку на агрегаторе, и когда-нибудь она сформируется.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Правильно.
#
# </div>

# %% [markdown]
# # 5 Предобработка critic_score

# %% [raw]
# #Заменили все значения нан на TBD
# #Сделали срез
# #Вывели его
# #df['critic_score'] = df['critic_score'].fillna('tbd')
# #critical_tbd = df.query('critic_score == "tbd"')
# #critical_tbd

# %% [raw]
# #Строим две сводные таблицы всего игры без оценок пользователя и всего игр вышедших по платформам
# #i = df.pivot_table(index='platform', values='critic_score',aggfunc='count').sort_values(by='critic_score')
# #g = critical_tbd.pivot_table(index='platform', values='critic_score',aggfunc='count').sort_values(by='critic_score')
# #Вычитаем для эксперимента
# #total = i -g
# #Посчитали количество значений ровно столько, сколько заполнено
# #total.sum()

# %% [raw]
# #В таблице получили данные о старых платформах и на них нету оценок. что логично.
# #total.sort_values(by='critic_score').plot(grid=True, kind='barh', figsize=(5,10), fontsize=10)

# %% [markdown]
# <div class="alert alert-block alert-info">
# Провели выше эксперимент. получили вроде бы адекватные данные. Да на старых платформах нету оценок критиков.
# Но мы знаем из иследований выше что там значений не так много. а мы при total = i -g вычитали из всех строк 8578 значений и получили 8137 строк.
# <div>

# %% [raw]
# #Сделали сводную таблицу по общим продажам в играх без оценки
# #all_regio = critical_tbd.query('year_of_release > 2004')
# #all_regio.pivot_table(index='name', values='all_region_sales').sort_values(ascending=False, by='all_region_sales').head(20)

# %% [markdown]
# <div class="alert alert-block alert-info">
# Получили сводную таблицу по количеству продаж в играх которых нет оценки критика. и результат очень странный.
# Список состоит их релизов которые имеют весомый вес среди критиков и фанатом, но на них нетку оценко.
#
# <div>

# %% [raw]
# #ВЗяли одну игру из сводной таблицы
# #critical_tbd.query('name =="the last of us"')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Игра the last of us очень популярна, платформа пс4. Это ремастер игры с пс3 и она также имела оценки и отзывыв игроков и рейтинг.
# <div>

# %% [raw]
# #ВЗяли одну игру из сводной таблицы
# #critical_tbd.query('name =="the legend of zelda: ocarina of time"')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Отличный пример на the legend of zelda: ocarina of time. Игра выходила на nintendo 64 в 1998, это игра с самой высокой оценкой в мире.
#
# По Версии метакритик составляет 99 баллов. (https://www.metacritic.com/game/nintendo-64/the-legend-of-zelda-ocarina-of-time)
#
# Релиз на nintendo 3ds имеет 94 балла.(https://www.metacritic.com/game/3ds/the-legend-of-zelda-ocarina-of-time-3d)
#
# Вывод данные по оценкам критиков не отоброжают какую либо действительность.
# <div>

# %% [markdown]
# # Вывод предобработка critic_score

# %% [markdown]
# <div class="alert alert-block alert-info">
# Провели предобработку данных столбца critic_score и выяснили, что данные не отражают действительность.
#
# Принято решение оставить данные как есть.
#
# Возможно ошибка выгрузки. Так как много популярный игр с большими продажами, крупные релизы всегда обозревают критики.
#
# Данные нельзя удалять, там где нету обзоров от критиков есть продажи.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Верно.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Предобработка critic_score будет вся задокументирована.
# <div>

# %% [markdown]
# #  6 Построим гистограммы на обработанные данные

# %%
df['platform'].sort_values(kind='heapsort').hist(figsize=(13, 5),bins=15,xlabelsize=10,xrot=90)
plt.ylabel('Количество релизов')
plt.xlabel('платформы')
# Out:
# Text(0.5, 0, 'платформы')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# На гистограмме видно на каких платформ, сколько выходило игр.
# Чем популярне платформа, тем больше было выщуено игр разных жанров на ней.
# Можем сказать о успешности платформы от количества разнообразных релизов.
#
# <div>

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Отсортируй.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Пытался отсорировать, нашел в инструкции к pandas Series.sort_values()
# kind{‘quicksort’, ‘mergesort’, ‘heapsort’, ‘stable’}, default ‘quicksort’
#
# Сортирует, правда только по индексу...
#
# <div>

# %%
df['year_of_release'].hist()
plt.ylabel('Количество релизов')
plt.xlabel('года')
# Out:
# Text(0.5, 0, 'года')

# %% [markdown]
# <div class="alert alert-block alert-info">
# На гистограмме хорошо видно что основной рост количества выпускаемых игр увеличисля после 2001-2002 года.
# Пик в 2010-2012 год и падение в 2013-2016 году.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %%
df['genre'].hist(figsize=(15, 5),bins=15,xlabelsize=10)
plt.ylabel('Количество релизов')
plt.xlabel('Жанры')
# Out:
# Text(0.5, 0, 'Жанры')

# %% [markdown]
# <div class="alert alert-block alert-info">
# На данной гистограмме видно популярность разных жанров.
# Самый популярный жанр action и  самый не популярный это puzzle.
# <div>

# %%
df['na_sales'].hist()
plt.ylabel('Количество релизов')
plt.xlabel('продажи')
# Out:
# Text(0.5, 0, 'продажи')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Продажи по северной америке , самый крупный рынок имеет жирные хвосты за 40 миллионов копий! это очень круто!
# в среднем продажи можно считать успешными от 500 тысяч до  1 мл копий. На гистограмме видно как большиство релизо состредоточено примерно в отметке от до 3.5мл копий.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %%
df['eu_sales'].hist()
plt.ylabel('Количество релизов')
plt.xlabel('продажи')
# Out:
# Text(0.5, 0, 'продажи')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Европейский рынок немного скромнее, также имеет жирные хвосты в районе 30 милилонов копий.
# В среднем продажи сосредоточены от 500 тысяч  мл до 2.5 мл копий.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %%
df['jp_sales'].hist()
plt.ylabel('Количество релизов')
plt.xlabel('продажи')
# Out:
# Text(0.5, 0, 'продажи')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Японский рынок еще более скромный, хвосты на гистограмме составляют около 12 миллионов .
# Успешный релиз можно назвать от 500 тысяч копий до 1 мл.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Все правильно.
#
# </div>

# %%
df['other_sales'].hist()
plt.ylabel('Количество релизов')
plt.xlabel('продажи')
# Out:
# Text(0.5, 0, 'продажи')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Продажи по миру или мировые продажи. Все остальные страные которые не входят в три крупных рынка.
# Хвост на гистограмме составляет порядка 15 мл.
# В среднем успешным релиз можно назвать от 500 тысяч копий до 1 мл.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Миллилитров?
#
# </div>

# %%
df['critic_score'].hist()
plt.ylabel('Количество релизов')
plt.xlabel('Оцененые критиками')
# Out:
# Text(0.5, 0, 'Оцененые критиками')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Большой плато по  оценке игр от 55 до 90 баллов.
#
# Уникальыне релизы стремятся к 100 баллам, видно что таких релизов гораздо меньше.
#
# Очень много релизов имеет оценку 65-80 баллов.
#
# Видно также на гистограмме что критики оценивают мало неудачных игр.
#
# Можно сделать субьективный вывод если игра имеет от 65 баллов, то она может вам тоже понравиться.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец.
#
# </div>

# %%
df['user_score'].sort_values().hist(figsize=(10, 3),bins=5,xlabelsize=7,xrot=90)
plt.ylabel('Количество релизов')
plt.xlabel('Оцененые пользователями')
# Out:
# Text(0.5, 0, 'Оцененые пользователями')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Пользовательские оценки от мало до велика. Сложно в таком орентироваться.
# Много значений 0. Игры не оцененые пользователями
#
# Пользователи если оценивают игры то многие их оценки находятся от 55 до 90 баллов
#
# Вывод - проще ориентироваться на вкус критика, чем пользователя.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %%
df['all_region_sales'].hist()
plt.ylabel('Количество релизов')
plt.xlabel('Суммарыне продажи по всем регионам')
# Out:
# Text(0.5, 0, 'Суммарыне продажи по всем регионам')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Продажи по всем регионам, самый жирный хвост, уходит за 80 миллионов.
# в среднем релизы все находятся  в диапазоне от 500 тыся копий  до 10 миллионов.
# <div>

# %%
df['rating_name'].hist(figsize=(5,5),xlabelsize= 7,xrot=90)
plt.ylabel('Количество релизов')
plt.xlabel('Виды рейтинга')
# Out:
# Text(0.5, 0, 'Виды рейтинга')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# На гистограмме видно распределение рейтинга по количеству релизов
#
# 4000 релизов имеют рейтинг любой возраст.
#
# 6700 - нет рейтинга. Изучили этот вопрос в предобработке выше.
#
# Релизы от 17 лет и от 10 лет имеют примерно один вес на гистограмме.
#
# Почти нет релизов только для взрослых  и ожидается рейтинг, примерно 17+
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец.
#
# </div>

# %% [markdown]
# # Вывод Предобработка данных

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# -Привели к общему нижнему региструстру все столбца датафрейма и строки в колонка name, genre, platform.
#
# -В столбцах name, genre, platform - дополнительно проверили на явные дубликаты.
#
# ### Опишите, в каких столбцах заменили тип данных и почему
# -Предобработка name и genre - обнаружено 2 игры 1993 года выпуска на платформе sega genesis. Решено оставить как есть.
#
# -Обработали пропущенные года. выяснили на каких платформах и сколько пропущенно. Пропуски были в разных платформах и не могли влият на результат, всего таких пропусков было 269. Принято решение их удалить.
#
# -Были заменены форматы строк в год релиза - был float, год это целое число. Изменили на int
# Оценк пользователей имели формат обьект , изменили на float
#
# ### Обработайте пропуски при необходимости
# -Обработали пропуски в rating сделали список rating_name с более удобным и понятным неймингом.
#
#     'Любой возраст', 'нет рейтинга',
#     'От 17 лет', 'От 12 лет',
#     'от 10 лет', 'Только для взрослых',
#     'Ожидается рейтинг, примерно 17+'
# Нашли дубликат в rating 'E' и 'K-A'.
#     'K-A' устаревший вариант, сейчас не используют. Сделали общий нейминг 'Любой возраст'.
#
#
# ### Объясните, почему заполнили пропуски определённым образом или почему не стали это делать
# Выснили что до 1994 года не оценивались игры по рейтингам, в 1994 году основали ESBR (рейтинговая компания в США).
# Решил не заполнять пропущенные значения в rating, это должны делать специалисты, я не могу оценить игру на какой либо из рейтингов.
#
# ### Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей, Отдельно разберите это значение и опишите, как его обработать
# -Обработали user_score - значения TBD , это те значения которые сформируются когда будет накоплено достаточно оценок на игру, значит в данном случае пока оценка не сформирована это значение 0.
# Были изучены данные и решено переименовать все значения nan в 0, пользователи могу проходить игры и ставить оценки, когда им удобно, значит рейтинг может сформироваться когда-то.
# Также при анализе critical_score было заменено , что крупные релизы не имеют ни пользовательских оценок и оценок критиков.
#
# ### Опишите причины, которые могли привести к пропускам
# -Обрабтали critical_score, обнаружены очень крупные релизы без оценок.
#     Возможно ошибка при выгрузке. В предобработке есть пример разбора.
#     Очень хорошо видно, что это ошибка на примере legend of zelda ocarina of time - самая высоко оцененная игра в мире. 99 баллов по мнению метакритик.
#     На основани разбора в предобработке данных решено оставить значения без изменеий в столбце critical_score.
#
# -Построили гистограммы на обработанные данные с описанием.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Отлично.
#
# </div>

# %% [markdown]
# ## Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам.

# %%
#Построили сводную таблицу год и сумма продаж за этот год
df.pivot_table(index='year_of_release', values='all_region_sales', aggfunc='mean') \
.sort_values(by='year_of_release', ascending=False).plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
plt.ylabel('Год релиза')
plt.xlabel('Сумма продаж')
# Out:
# Text(0.5, 0, 'Сумма продаж')

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Отсортируй.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# На это графике мы видим, что в 1984/1985 и 1988-1990 год, игры сделали огромную годовую вырочку.
# Хотя релизов по факту было не много.
# В тоерии каждая игра была хитом. А по факту, отсутсвие выбора, покупаешь что есть:(
# <div>

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы

# %%
#Сделали таблицу продаж количества видов игр в год 
df.pivot_table(index='year_of_release', values='name', aggfunc='count') \
.plot(grid=True, kind='barh', figsize=(5,7), fontsize=10)
plt.ylabel('Год релиза')
plt.xlabel('Количество релизов')
# Out:
# Text(0.5, 0, 'Количество релизов')

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %% [markdown]
# ### Важны ли данные за все периоды?

# %% [markdown]
# # Вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Количество релизо после 1994 начало рости, можно сказать что игровая индустрия становилась пополярней.
# Игр стало больше, но доля игр которые продавались бы миллиона сильно не увеличилась.
#
# До 1994 года, ролизов меньше, но игры продавались большими тиражами и зарабатывали много денег.
#
# Если рассматривать данные со стороны количества релизов, то до 1994 года не особо интересно.
# Можем по ним изучить какие популярны серии тогда зарадились.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Правильно.
#
# </div>

# %% [markdown]
# ### Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.

# %%
#Сделали сводную таблицу с наибольшими суммарными продажами по платформам
df.pivot_table(index='platform', values='all_region_sales',aggfunc='sum') \
.sort_values(by='all_region_sales',ascending=False).head(5)
# Out:
#           all_region_sales
# platform
# ps2                1233.56
# x360                961.24
# ps3                 931.34
# wii                 891.18
# ds                  802.78

# %%
# График суммарных продаж по топ 5 платформам
df.pivot_table(index='platform', values='all_region_sales',aggfunc='sum') \
.sort_values(by='all_region_sales',ascending=False).head(5).plot(grid=True, kind='barh', figsize=(7,3), fontsize=10)
plt.ylabel('Платформы топ 5')
plt.xlabel('Cумма продаж всех регионов')
# Out:
# Text(0.5, 0, 'Cумма продаж всех регионов')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Нашли самые крупные платформы по продажам
# Ps2, Xbox360, Ps3, Wii, Ds.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Отлично.
#
# </div>

# %% [markdown]
# # Playstation 2

# %%
#Сделали срез по платформе Playstation 2
df_ps2 = df.query('platform == "ps2"').sort_values(by='all_region_sales',ascending=False)
df_ps2.head(5)
# Out:
#                              name platform  year_of_release   genre  na_sales  \
# 17  grand theft auto: san andreas      ps2             2004  action      9.43
# 24    grand theft auto: vice city      ps2             2002  action      8.41
# 28         gran turismo 3: a-spec      ps2             2001  racing      6.85
# 38           grand theft auto iii      ps2             2001  action      6.99
# 48                 gran turismo 4      ps2             2004  racing      3.01
#
#     eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 17      0.40      0.41        10.57          95.0         9.0      M
# 24      5.49      0.47         1.78          95.0         8.7      M
# 28      5.09      1.87         1.16          95.0         8.4      E
# 38      4.51      0.30         1.30          97.0         8.5      M
# 48      0.01      1.10         7.53          89.0         8.5      E
#
#     all_region_sales    rating_name
# 17             20.81      От 17 лет
# ...

# %%
#Узнали сколько лет платформа существовала
df_ps2['year_of_release'].sort_values().unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011])

# %%
#Сводная таблица по продажам на платформе Playstation 2 по годам
df_ps2.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2000                          82            39.17
# 2001                         185           166.43
# 2002                         280           205.38
# 2003                         256           184.31
# 2004                         259           211.81
# 2005                         260           160.66
# 2006                         259           103.42
# 2007                         214            75.99
# 2008                         191            53.90
# 2009                          96            26.40
# 2010                          38             5.64
# 2011                           7             0.45

# %%
#График продаж релизов Playstation 2 по годам
df_ps2.pivot_table(index=['year_of_release','platform'], values='all_region_sales', aggfunc=['count', 'sum']) \
.plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
plt.ylabel('Год и Платформа Playstation 2')
plt.xlabel('Cумма продаж во всех регионах Playstation 2')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Playstation 2')

# %%
df_ps2.query('year_of_release == 2004').sort_values(by='all_region_sales',ascending=False).head(5)
# Out:
#                                               name platform  year_of_release  \
# 17                   grand theft auto: san andreas      ps2             2004
# 48                                  gran turismo 4      ps2             2004
# 113                   need for speed underground 2      ps2             2004
# 186  dragon quest viii: journey of the cursed king      ps2             2004
# 238                                madden nfl 2005      ps2             2004
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 17         action      9.43      0.40      0.41        10.57          95.0
# 48         racing      3.01      0.01      1.10         7.53          89.0
# 113        racing      2.71      3.02      0.08         1.09          82.0
# 186  role-playing      0.65      0.75      3.61         0.20          89.0
# 238        sports      4.18      0.26      0.01         0.08          91.0
#
# ...

# %%
#Количество проданных 
df_ps2['all_region_sales'].sum()
# Out:
# 1233.5600000000002

# %%
#Всего выпущено игр
df_ps2['all_region_sales'].count()
# Out:
# 2127

# %% [markdown]
# # Вывод платформа Playstation 2

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# В 2000 году на Playstation 2 было выпущено 82 игры, сумма проданных копий составила 39.17 мл.
#
# В 2001 году было выпушено 185 игр, продажи увеличилсь в 4 раза в сравнении с 2000 годом и составили 166.43 мл.
#
# В 2002 году наблюдаем очередной рост популярности платформы и рост продаж игр.
# Количество вышедших игр достигло 280 штук, а количество броданных копий 205.38 мл.
#
# C 2003 по 2006 - количество игр выходит на плато, и поддерживается каждый год в районе примерном 256-260.
# Продажи с 2003 по 2011 - идет уменьшене доходов с продаж игр каждый год, исключением является 2004 год.
#
# В 2004 году есть увеличение суммы за продажи игр, без увеличения количества выпущенных игр. Сделали срез и нашли два крупных релиза "grand theft auto: san andreas" продалась во всех регионах в количестве 20.81 мл копий и "gran turismo 4" 11.65 мл копий, которые послужили увечиленному доходу в этот год.
#
# В 2009 году идет резкое уменьшение релизов всего 96 штук.
#
# Платформа Playstation 2  просуществовала 11 лет вышло 2127 игр и продано их на сумму 1 миллиард 233 миллиона.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец.
#
# </div>

# %% [markdown]
# #  Xbox 360

# %%
#Сделали срез по платформе Xbox 360
df_x360 = df.query('platform == "x360"').sort_values(by='all_region_sales',ascending=False)
df_x360.head(5)
# Out:
#                               name platform  year_of_release    genre  \
# 14              kinect adventures!     x360             2010     misc
# 23              grand theft auto v     x360             2013   action
# 29  call of duty: modern warfare 3     x360             2011  shooter
# 32         call of duty: black ops     x360             2010  shooter
# 35      call of duty: black ops ii     x360             2012  shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 14     15.00      4.89      0.24         1.69          61.0         6.3
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 29      9.04      4.24      0.13         1.32          88.0         3.4
# 32      9.70      3.68      0.11         1.13          87.0         6.3
# 35      8.25      4.24      0.07         1.12          83.0         4.8
#
#    rating  all_region_sales    rating_name
# 14      E             21.82  Любой возраст
# ...

# %%
#Узнали сколько лет платформа существовала
df_x360['year_of_release'].sort_values().unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016])

# %%
#Сводная таблица по продажам на платформе xbox360 
df_x360.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2005                          18             8.25
# 2006                          93            51.62
# 2007                         123            95.41
# 2008                         146           135.26
# 2009                         172           120.29
# 2010                         182           170.03
# 2011                         206           143.84
# 2012                         106            99.74
# 2013                          75            88.58
# 2014                          63            34.74
# 2015                          35            11.96
# 2016                          13             1.52

# %%
#График продаж релизов Xbox360 по годам
df_x360.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum']) \
.plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
plt.ylabel('Год и Платформа Xbox360')
plt.xlabel('Cумма продаж во всех регионах Xbox360')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Xbox360')

# %%
#Посмотрим какой релиз повлиял на увеличение продаж в 2013 году.
df_x360.query('year_of_release == 2013').sort_values(by='all_region_sales', ascending=False).head(5)
# Out:
#                      name platform  year_of_release    genre  na_sales  \
# 23     grand theft auto v     x360             2013   action      9.66
# 60   call of duty: ghosts     x360             2013  shooter      6.73
# 72              minecraft     x360             2013     misc      5.70
# 271               fifa 14     x360             2013   sports      0.92
# 380         battlefield 4     x360             2013  shooter      2.15
#
#      eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 23       5.14      0.06         1.41          97.0         8.1      M
# 60       2.56      0.04         0.91          73.0         2.6      M
# 72       2.65      0.02         0.81           NaN         0.0    NaN
# 271      2.89      0.01         0.40          84.0         4.2      E
# 380      1.01      0.02         0.31          79.0         5.6      M
#
#      all_region_sales    rating_name
# 23              16.27      От 17 лет
# 60              10.24      От 17 лет
# ...

# %%
#Сумма всех проданных игр за все года
df_x360['all_region_sales'].sum()
# Out:
# 961.2400000000002

# %%
#Количество проданных игр за все года
df_x360['all_region_sales'].count()
# Out:
# 1232

# %% [markdown]
# # Вывод платформа Xbox 360

# %% [markdown]
# <div class="alert alert-block alert-info">
# Xbox 360 вышел в 2005 году количество игр вышло в этот год 18 релизов, а продажи составили 8.25 мл.
# В сравнении с Playstation 2 первый год продаж очень плохой.
#
# С 2006 по 2011 год идет резкое увеличени релизов  и суммма продаж.
#
# Самый прибыльный 2010 год сумма релизов составила 182 видов сумма проданных игр 170.03 мл.
#
# С 2012 года по 2016 идет , уменьшение релизов на платформе и сумма дохода.
#
# Также имеем интересный 2013 год. Сумма дохода 88.58 мл привысила количество релизов 75 видов. Сделали срез и нашли игру.
# Такое влияние могла оказать "grand theft auto v" - количество проданных копий 16.27мл.
#
# Последний актуальный 2016 год у Xbox360 составил продажи 1.52 мл и 13 релизов.
#
# Платформа Xbox360 просуществовала 11 лет и было продано 1232 наименований на общую сумму 961 миллион.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Все правильно.
#
# </div>

# %% [markdown]
# # Playstation 3

# %%
#Сделали срез по платформе Playstation 3
df_ps3 = df.query('platform == "ps3"').sort_values(by='all_region_sales',ascending=False)
df_ps3.head(5)
# Out:
#                               name platform  year_of_release    genre  \
# 16              grand theft auto v      ps3             2013   action
# 34      call of duty: black ops ii      ps3             2012  shooter
# 37  call of duty: modern warfare 3      ps3             2011  shooter
# 41         call of duty: black ops      ps3             2010  shooter
# 54                  gran turismo 5      ps3             2010   racing
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 34      4.99      5.73      0.65         2.42          83.0         5.3
# 37      5.54      5.73      0.49         1.57          88.0         3.2
# 41      5.99      4.37      0.48         1.79          88.0         6.4
# 54      2.96      4.82      0.81         2.11          84.0         7.5
#
#    rating  all_region_sales    rating_name
# 16      M             21.05      От 17 лет
# ...

# %%
#Узнали сколько лет платформа существовала
df_ps3['year_of_release'].sort_values().unique()
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
#Сводная таблица по продажам на платформе Playstation 3
df_ps3.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2006                          27            20.96
# 2007                          90            73.19
# 2008                         138           118.52
# 2009                         162           130.93
# 2010                         181           142.17
# 2011                         215           156.78
# 2012                         148           107.36
# 2013                         126           113.25
# 2014                         108            47.76
# 2015                          73            16.82
# 2016                          38             3.60

# %%
#График продаж релизов Playstation3 по годам
df_ps3.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum']) \
.plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
plt.ylabel('Год и Платформа Playstaion 3')
plt.xlabel('Cумма продаж во всех регионах Playstaion 3')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Playstaion 3')

# %% [markdown]
# #Посмотрим какой релиз повлиял на увеличение продаж в 2013 году.
# df_ps3.query('year_of_release == 2013').sort_values(by='all_region_sales', ascending=False).head(5)

# %%
#Сумма всех проданных игр за все года
df_ps3['all_region_sales'].sum()
# Out:
# 931.34

# %%
#Количество проданных игр за все года
df_ps3['all_region_sales'].count()
# Out:
# 1306

# %% [markdown]
# # Вывод платформа Playstation3

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Выход платформы Playstation 3 состоял в 2006 году. Релизов в этот год вышло 27 видов, а продажи составили 20.96 мл.
#
# С 2007 года до 2011 года идет равномерный рост как доходов так и релизов.
#
# 2011 год является самым большим по продажам, которые составили 156.78 мл  и количество релизов 215 видов.
#
# С 2012 по 2016 идет уменьшение доходов и релизов.
#
# Также как и на xbox360 год 2013 является аномальным, в этот год на Playstation3 вышла тоже Gta5 и она увеличила продажи.
#
# Платформа Playstation 3 просуществовала 10 лет и было продано 1306 наименований на общую сумму 931.34 миллион.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %% [markdown]
# # Nintendo Wii

# %%
#Сделали срез по платформе Nintendo Wii
df_wii = df.query('platform == "wii"').sort_values(by='all_region_sales',ascending=False)
df_wii.head(5)
# Out:
#                         name platform  year_of_release     genre  na_sales  \
# 0                 wii sports      wii             2006    sports     41.36
# 2             mario kart wii      wii             2008    racing     15.68
# 3          wii sports resort      wii             2009    sports     15.61
# 7                   wii play      wii             2006      misc     13.96
# 8  new super mario bros. wii      wii             2009  platform     14.44
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 7      9.18      2.93         2.84          58.0         6.6      E
# 8      6.94      4.70         2.24          87.0         8.4      E
#
#    all_region_sales    rating_name
# 0             82.54  Любой возраст
# ...

# %%
#Узнали сколько лет платформа существовала
df_wii['year_of_release'].sort_values().unique()
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
#Сводная таблица по продажам на платформе Nintendo Wii
df_wii.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2006                          44           137.15
# 2007                         185           152.77
# 2008                         282           171.32
# 2009                         325           206.97
# 2010                         253           127.95
# 2011                         143            59.65
# 2012                          31            21.71
# 2013                          12             8.59
# 2014                           6             3.75
# 2015                           4             1.14
# 2016                           1             0.18

# %%
#График продаж релизов Nintendo Wii по годам
df_wii.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum']) \
.plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
plt.ylabel('Год и Платформа Nintendo Wii')
plt.xlabel('Cумма продаж во всех регионах Nintendo Wii')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Nintendo Wii')

# %%
#Посмотрим какой релиз повлиял на увеличение продаж в 2013 году.
df_wii.query('year_of_release == 2006').sort_values(by='all_region_sales', ascending=False).head(5)
# Out:
#                                        name platform  year_of_release   genre  \
# 0                                wii sports      wii             2006  sports
# 7                                  wii play      wii             2006    misc
# 107  the legend of zelda: twilight princess      wii             2006  action
# 503                 warioware: smooth moves      wii             2006  puzzle
# 717         super monkey ball: banana blitz      wii             2006    misc
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0       41.36     28.96      3.77         8.45          76.0         8.0
# 7       13.96      9.18      2.93         2.84          58.0         6.6
# 107      3.74      2.14      0.60         0.68          95.0         9.0
# 503      0.86      1.04      0.73         0.26          83.0         7.4
# 717      1.05      0.91      0.04         0.24          74.0         5.7
#
#     rating  all_region_sales    rating_name
# ...

# %%
#Сумма всех проданных игр за все года
df_wii['all_region_sales'].sum()
# Out:
# 891.1800000000002

# %%
#Количество проданных игр за все года
df_wii['all_region_sales'].count()
# Out:
# 1286

# %% [markdown]
# # Вывод  платформа Nintendo Wii

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Выход платформы Nintendo Wii состоялся в 2006 году.
# За этот год было продано 44 релиза на общую сумму 137.15 мл.
#
# С 2006 до 209 года увеличиватся доходы и количество резов, с 2010 по 2016 уменьшаются как количество игра выпущенных так и доходы.
#
# Можно отметить, что на старте при небольшом количестве релизов было заработало больше чем на всех расмотренных платформах в первый год продаж. Этому способствует Wii Sports - она прода в количестве 82.54 мл, данная игра шла вместе с консолью.	 (На Nintendo Wii было представлен новый вид управление, а не классический геймпад, могло послужить интересу покупателей к консоли нинтендо) Последущие года количество релизо больше чем сумма всех доходов.
#
# В 2016 году мы видим что вышла 1 наименование игры и продано на сумму 180 тысяч.(Нам известно,что данные не полные за 2016, не будем на это обращать внимание)
#
# Всего платформа Nintendo Wii просуществовала 10 лет. Было продано 1286 наименований игр на общую сумму 891.18 миллионов.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Верно.
#
# </div>

# %% [markdown]
# # Nintendo Ds

# %%
#Сделали срез по платформе Nintendo Ds
df_ds = df.query('platform == "ds"').sort_values(by='all_region_sales',ascending=False)
df_ds.head(5)
# Out:
#                                             name platform  year_of_release  \
# 6                          new super mario bros.       ds             2006
# 10                                    nintendogs       ds             2005
# 11                                 mario kart ds       ds             2005
# 19  brain age: train your brain in minutes a day       ds             2005
# 20                 pokemon diamond/pokemon pearl       ds             2006
#
#            genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 6       platform     11.28      9.14      6.50         2.88          89.0
# 10    simulation      9.05     10.95      1.93         2.74           NaN
# 11        racing      9.71      7.47      4.13         1.90          91.0
# 19          misc      4.74      9.20      4.16         2.04          77.0
# 20  role-playing      6.38      4.46      6.04         1.36           NaN
#
#     user_score rating  all_region_sales    rating_name
# ...

# %%
#Узнали сколько лет платформа существовала
df_ds['year_of_release'].sort_values().unique()
# Out:
# array([1985, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013])

# %%
#Сводная таблица по продажам на платформе Nintendo Ds
df_ds.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 1985                           1             0.02
# 2004                          23            17.27
# 2005                         118           130.14
# 2006                         201           119.81
# 2007                         376           146.94
# 2008                         492           145.31
# 2009                         403           119.54
# 2010                         323            85.02
# 2011                         153            26.18
# 2012                          23            11.01
# 2013                           8             1.54

# %%
#График продаж релизов Nintendo Wii по годам
df_ds.pivot_table(index='year_of_release', values='all_region_sales', aggfunc=['count', 'sum']) \
.plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
plt.ylabel('Год и Платформа Nintendo Ds')
plt.xlabel('Cумма продаж во всех регионах Nintendo Ds')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Nintendo Ds')

# %%
#Посмотрим что за релиз у Nintendo Ds в 1985 году.
df_ds.query('year_of_release == 1985').sort_values(by='all_region_sales', ascending=False).head(5)
# Out:
#                                       name platform  year_of_release   genre  \
# 15957  strongest tokyo university shogi ds       ds             1985  action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15957       0.0       0.0      0.02          0.0           NaN         0.0
#
#       rating  all_region_sales   rating_name
# 15957    NaN              0.02  нет рейтинга

# %%
#Проверили данная игра существовала и вышла в япони, переименовали год 
df['year_of_release'] = df['year_of_release'].replace(1985, 2010)

# %%
# Проверили что все переименовалось
df_ds.query('name == "strongest tokyo university shogi ds"').sort_values(by='all_region_sales', ascending=False).head(5)
# Out:
#                                       name platform  year_of_release   genre  \
# 15957  strongest tokyo university shogi ds       ds             1985  action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15957       0.0       0.0      0.02          0.0           NaN         0.0
#
#       rating  all_region_sales   rating_name
# 15957    NaN              0.02  нет рейтинга

# %%
#Сумма всех проданных игр за все года
df_ds['all_region_sales'].sum()
# Out:
# 802.78

# %%
#Количество всех проданных игр за все года
df_ds['all_region_sales'].count()
# Out:
# 2121

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Выход платформы Nintendi Ds состоялся в 2004 году, вышло 23 наименование и проданно на сумму 17.27 мл.
# В 2005 году происходит рост вышедных наимнований и соствляет 118, а продажи составили 130.14 мл.
# В 2006 доход уменшается в сравнении с 2005 годом и соствляет 119.81 мл. , но количество наименований увеличивается и состтавляет 201 в 2015 релизов было 118 ,увеличение почти в два раза.
#
# В 2007-2008 годе доход выходит на плато и состовляет 146-145 мл, но самое большое количество релизов было в 2008 году. вышло 492 наименования.
#
# С 2009 года до 2013 идет уменьше доходов и количесто релизов.
#
# Платформа Nintendo Ds просуществовала 9 лет. Вышло 2121 наименование игр на общую сумму 802.78 мл.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %%
#Соеденим все наши таблицы в одну большую
df_all = df_ps2.append((df_x360, df_ps3, df_wii, df_ds), ignore_index=False, verify_integrity=False, sort=None)
# Out:
# C:\Users\hulyg\AppData\Local\Temp\ipykernel_15720\4260390711.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_ps2.append((df_x360, df_ps3, df_wii, df_ds), ignore_index=False, verify_integrity=False, sort=None)
# C:\Users\hulyg\AppData\Local\Temp\ipykernel_15720\4260390711.py:2: FutureWarning: Passing non boolean values for sort is deprecated and will error in a future version!
#   df_all = df_ps2.append((df_x360, df_ps3, df_wii, df_ds), ignore_index=False, verify_integrity=False, sort=None)

# %%
#Проверяем
df_all.head(5)
# Out:
#                              name platform  year_of_release   genre  na_sales  \
# 17  grand theft auto: san andreas      ps2             2004  action      9.43
# 24    grand theft auto: vice city      ps2             2002  action      8.41
# 28         gran turismo 3: a-spec      ps2             2001  racing      6.85
# 38           grand theft auto iii      ps2             2001  action      6.99
# 48                 gran turismo 4      ps2             2004  racing      3.01
#
#     eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 17      0.40      0.41        10.57          95.0         9.0      M
# 24      5.49      0.47         1.78          95.0         8.7      M
# 28      5.09      1.87         1.16          95.0         8.4      E
# 38      4.51      0.30         1.30          97.0         8.5      M
# 48      0.01      1.10         7.53          89.0         8.5      E
#
#     all_region_sales    rating_name
# 17             20.81      От 17 лет
# ...

# %%
#Строим сводную таблицу год релиза, платформа, суммарые продажи
df_all.pivot_table(index=['year_of_release','platform'], values='all_region_sales', aggfunc=['count','sum'])
# Out:
#                                     count              sum
#                          all_region_sales all_region_sales
# year_of_release platform
# 1985            ds                      1             0.02
# 2000            ps2                    82            39.17
# 2001            ps2                   185           166.43
# 2002            ps2                   280           205.38
# 2003            ps2                   256           184.31
# 2004            ds                     23            17.27
#                 ps2                   259           211.81
# 2005            ds                    118           130.14
#                 ps2                   260           160.66
#                 x360                   18             8.25
# 2006            ds                    201           119.81
#                 ps2                   259           103.42
#                 ps3                    27            20.96
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Сделали сводную таблицу удобно смотреть,в какие года какие платформы были актуальны по списку топ5.
# <div>

# %%
#Тыблица общих доход платформ и релизов из топ5
df_all.pivot_table(index='platform', values='all_region_sales', aggfunc=['sum', 'count'])
# Out:
#                       sum            count
#          all_region_sales all_region_sales
# platform
# ds                 802.78             2121
# ps2               1233.56             2127
# ps3                931.34             1306
# wii                891.18             1286
# x360               961.24             1232

# %%
#По сводной таблице строим график
df_all.pivot_table(index=['year_of_release','platform'], values='all_region_sales',aggfunc=['count','sum']) \
.plot(grid=True, kind='barh', figsize=(7,15), fontsize=10)
# Out:
# <AxesSubplot:ylabel='year_of_release,platform'>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Здорово, но я бы повернул.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Мы тут как волшебники, повернул! :)
# <div>

# %% [markdown]
# ### За какой характерный срок появляются новые и исчезают старые платформы?

# %% [markdown]
# # Общий вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Мы узнали
# Платформа Playstation 2 просуществовала 11 лет.
# Платформа Xbox360 просуществовала 11 лет.
# Платформа Playstation 3 просуществовала 10 лет.
# Платформа Nintendo Wii просуществовала 10 лет.
# Платформа Nintendo Ds просуществовала 9 лет
# В среднем платформа существует 10 лет и 2 месяца.
#
# В ходе анализы было установлено, что весь жизненый цикл платформ из списка топ 5 имеет нормальное распределение, идет рост продаж игр в регионах и количество выпускаемых релизов, имеет пик популярности  с максиммальным доходом и максимальное количество релизов,которые вышли в данны год. И постепенное снижением актуальности платформы и падением доходов и количества выпускаемых релизов, в среднем полный цикл происходит за 10 лет.
#
# Можно сказать медиана популярости консоли составляет 5 лет. Потом выходит новая консоль, и часть пользователей преходит на следующую актульную косноль.
#
# Также существую драйверы в виде игр, которые популярны среди пользователей и продаются большими тиражами. Даже если продажи игр и сумма выручки с них идет на спад, выпуск такого драйвера способствую получению допольнительно прибыли.
# Установили это на примере GTA 5, вышедшая на платформе Xbox360 и Playstation3
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо, но я бы рассмотрел все платформы, так как это помогло юы тебе корректнее выбрать актуальный период.
#
# </div>

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. **Не учитывайте в работе данные за предыдущие годы.**

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Взял актуальный период 5 лет с 2011 по 2015, мы знаем что в 2016 не хватает данных , решил его исключить.
#
# Взял платформы которые в продаже не более 6 лет. Потенциально они сейчас заходят на пик или на ходятся на пике(выше мы выяснили что в среднем успешная платформа живет 10 лет), проведем анализ данных платформ и проверим эту гипотезу.
#
# Данные платформы будут также актуальный для 2017 годa.
# Платформы кототорые будем изучать и почему
#
#    - Playstation 4 - Предыщдущая консоль Playstation 3 показала отличную прибыль в 931.34 мл и 1306 видов релизов и жизнь в 10 лет.
#    - Nintenda 3ds - Предыдущая консоль Nintendo Ds показала колосальное количество релизов 2121 видов и доход в 802.78 мл и просуществовала 9 лет.
#    - Playstation Vita - Рассмотрим новую портативную консоль от Sony.
#    - Xbox One - Предылущая консоль Xbox360 смогла предоставить общие продажи на 961.24 мл и вышло 1232 различные игры.
#    - Nintendo Wiiu - Предыдущая консоль от Nintendo Wii получила прибыль в размере 891.18 и на нее вышло 1286 разных игр.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Можно оставить и такой вариант, но это отразится на результате исследования. Смотри, у нас есть две новых платформы, обе вышли в 2013 году. Значит если мы возьмем, например 2012 год, то у старых платформ будет фора в год, и по результатам исследования у них будут продажи лучше, чем у новых платформ. Поэтому я тебе рекомендую провести исследование с 2013 года.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Согласен. вернулся выше посмотрели график релизов по годам и по платформам.
# Проведем тогда иследование с 2013 по 2015 год.
# <div>

# %%
#Актуальный период определии как 2013 -2015 год
df_curr = df.loc[(df['year_of_release'] >= 2013 ) & (df['year_of_release'] <=  2015 )]

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ Комментарий не соответствует коду.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Исправил
# <div>

# %%
#Проверили , что взяли нужные нам года.
df_curr ['year_of_release'].sort_values().unique()
# Out:
# array([2013, 2014, 2015])

# %%
#Открыли сводную таблицу по выбранным годам 
df_curr.head(5)
# Out:
#                          name platform  year_of_release         genre  \
# 16         grand theft auto v      ps3             2013        action
# 23         grand theft auto v     x360             2013        action
# 31  call of duty: black ops 3      ps4             2015       shooter
# 33        pokemon x/pokemon y      3ds             2013  role-playing
# 42         grand theft auto v      ps4             2014        action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38           NaN         0.0
# 33      5.28      4.19      4.35         0.78           NaN         0.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
#
#    rating  all_region_sales   rating_name
# 16      M             21.05     От 17 лет
# ...

# %%
# Сводная таблица по количеству проданных копий игр и количеству релизов вышедных релизов на каждой консоли
df_curr.groupby('platform').agg({'all_region_sales' : 'sum', 'name' : 'count' }) \
.sort_values(by='all_region_sales', ascending=False)
# Out:
#           all_region_sales  name
# platform
# ps4                 244.89   228
# ps3                 177.83   307
# x360                135.28   173
# xone                133.17   160
# 3ds                 128.11   257
# wiiu                 60.03   101
# pc                   34.18   135
# psv                  28.74   273
# wii                  13.48    22
# psp                   3.50    67
# ds                    1.54     8

# %% [markdown]
# <div class="alert alert-warning">
#
# **Артём:** 👉 Как раз здесь это хорошо видно. Лидером стала PS3 именно из-за форы. Если условия будут одинаковыми для всех, то и вывод изменится.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Переделал, данные стали более актуальными, для построения прогноза на 2017 год.
# <div>

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ

# %%
#Отсортировал график по сводной таблице платформа и суммма общих продаж с 2013 по 2015 год 
df_curr.pivot_table(index='platform', values='all_region_sales').sort_values(by='all_region_sales') \
.plot(grid=True, kind='bar', figsize=(10,3), fontsize=10)
# Out:
# <AxesSubplot:xlabel='platform'>

# %% [markdown]
# # Playstation 4

# %%
# Сделали срез по Playstation 4 
df_ps4=df_curr.query('platform == "ps4"')
df_ps4.head(5)
# Out:
#                               name platform  year_of_release    genre  \
# 31       call of duty: black ops 3      ps4             2015  shooter
# 42              grand theft auto v      ps4             2014   action
# 77                         fifa 16      ps4             2015   sports
# 87    star wars battlefront (2015)      ps4             2015  shooter
# 92  call of duty: advanced warfare      ps4             2014  shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 31      6.03      5.86      0.36         2.38           NaN         0.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
# 77      1.12      6.12      0.06         1.28          82.0         4.3
# 87      2.99      3.49      0.22         1.28           NaN         0.0
# 92      2.81      3.48      0.14         1.23          83.0         5.7
#
#    rating  all_region_sales    rating_name
# 31    NaN             14.63   нет рейтинга
# ...

# %%
#Года когда выходили на Playstation 4 игры
df_ps4['year_of_release'].unique()
# Out:
# array([2015, 2014, 2013])

# %%
#Сводная таблица количество релизов и сумма продаж по платформе Playstation 4
df_ps4.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2013                          16            25.99
# 2014                          75           100.00
# 2015                         137           118.90

# %%
#График релизо  и продаж на Playstation 4 
df_ps4.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum']) \
.plot(grid=True, kind='barh', figsize=(5,3), fontsize=10)
plt.ylabel('Год и Платформа Playstation4')
plt.xlabel('Cумма продаж во всех регионах Playstation4')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Playstation4')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Мы проанализировали платформу Playstation4 и выяснили, что на старте в 2013 году вышло всего 16 видов игр и продали на общую сумму 26 мл.
#
# В 2014 году происходит значительный рост релизов, который составил 75 видов игр и продажи достигли отметки в 100 мл.
# Значительный рост количество видом и сумма продаж выросла примерно в 4 раза.
#
# В 2015 году релизов увеличилось до 137 видов - рост составил почти в 2 раза, сумма общих дохов увеличилась не значительно на 18%.
#
# У платформы Playstation 4 прекрасный рост общий продаж и релизов каждый год. Предположу что в 2016 и 2017 мы увидим увиличение релизов и дохода. Предположу актуальность данной платформы минимум 10 лет :)
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Отлично.
#
# </div>

# %% [markdown]
# # Nintendo 3ds

# %%
#Построили срез по консоли Nintendo 3ds
df_3ds=df_curr.query('platform == "3ds"')
df_3ds.head(5)
# Out:
#                                           name platform  year_of_release  \
# 33                         pokemon x/pokemon y      3ds             2013
# 47   pokemon omega ruby/pokemon alpha sapphire      3ds             2014
# 96         super smash bros. for wii u and 3ds      3ds             2014
# 184                             tomodachi life      3ds             2013
# 235                 luigi's mansion: dark moon      3ds             2013
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 33   role-playing      5.28      4.19      4.35         0.78           NaN
# 47   role-playing      4.35      3.49      3.10         0.74           NaN
# 96       fighting      3.27      1.37      2.43         0.48           NaN
# 184    simulation      0.97      2.11      1.90         0.24           NaN
# 235        action      1.80      1.39      1.11         0.29          86.0
#
#      user_score rating  all_region_sales    rating_name
# ...

# %%
# Сколько лет выходят на нее игры
df_3ds['year_of_release'].unique()
# Out:
# array([2013, 2014, 2015])

# %%
#Сводная таблица количества и сумма продаж
df_3ds.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2013                          91            56.57
# 2014                          80            43.76
# 2015                          86            27.78

# %%
#График количества и сумма продаж
df_3ds.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum']) \
.plot(grid=True, kind='barh', figsize=(10,7), fontsize=10)
plt.ylabel('Год и Платформа Nintendo 3ds')
plt.xlabel('Cумма продаж во всех регионах Nintendo 3ds')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Nintendo 3ds')

# %%
df_3ds.query('year_of_release == 2013').sort_values(by='all_region_sales',ascending=False)
# Out:
#                                              name platform  year_of_release  \
# 33                            pokemon x/pokemon y      3ds             2013
# 184                                tomodachi life      3ds             2013
# 235                    luigi's mansion: dark moon      3ds             2013
# 385                              monster hunter 4      3ds             2013
# 448    the legend of zelda: a link between worlds      3ds             2013
# ...                                           ...      ...              ...
# 16045                    turbo: super stunt squad      3ds             2013
# 16342                          seisou no amazones      3ds             2013
# 16504          teenage mutant ninja turtles (3ds)      3ds             2013
# 16570                                    exstetra      3ds             2013
# 16648                                mushi bugyou      3ds             2013
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# В 2011 на старте продаж Nintendo 3ds количество релизов составило 116 видов, общая сумма продаж составила 63.20 мл.
#
# С 2012 по 2015 , мы видим что уменьшаются количество релизов и сумма вырученных продаж.
# В 2013 году есть увечиление продаж относительно соседних 2014 и 2012 года. Сделали срез и выяснили, что вышлла игр 'pokemon x/pokemon y' которая послужила драйвером продаж.
#
# Можем сделать вывод, что 2017 году данная консоль уже не будет актуальна на рынке.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Возможно.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Корректированный вывод.
#
# На графике отлично видно, что с 2013 по 2015 год  уменьшается общих доход с игр. но количество релизов примерно на одном уровне.
#
# Жаль на таких варинтах графиков не видно драйверов продаж, драйвер в целом не панацея.
# <div>

# %% [markdown]
# # Plastation Vita

# %%
#Делаем срез по платформе Playstation Vita
df_psv=df_curr.query('platform == "psv"')
df_psv.head(5)
# Out:
#                                    name platform  year_of_release  \
# 868                           minecraft      psv             2014
# 2566                killzone: mercenary      psv             2013
# 2569  final fantasy x / x-2 hd remaster      psv             2013
# 3086                       freedom wars      psv             2014
# 3127                      borderlands 2      psv             2014
#
#              genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 868           misc      0.18      0.64      0.90         0.24           NaN
# 2566       shooter      0.20      0.39      0.04         0.17          78.0
# 2569  role-playing      0.16      0.24      0.28         0.12          86.0
# 3086  role-playing      0.15      0.10      0.32         0.08          73.0
# 3127       shooter      0.32      0.16      0.01         0.15          64.0
#
#       user_score rating  all_region_sales   rating_name
# ...

# %%
#Года выхода игра на консоль
df_psv['year_of_release'].unique()
# Out:
# array([2014, 2013, 2015])

# %%
#Сводная таблица количества и продаж 
df_psv.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2013                          63            10.59
# 2014                         100            11.90
# 2015                         110             6.25

# %%
#График количество релизов и общих доходов
df_psv.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum']) \
.plot(grid=True, kind='barh', figsize=(5,5), fontsize=10)
plt.ylabel('Год и Платформа Playstation Vita')
plt.xlabel('Cумма продаж во всех регионах Playstation Vita')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Playstation Vita')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Старт продаж у платформы Playstation Vita в 2011, похож на старт продаж другой консоли от Sony(Playstation4).
# В 2012 года наблюдается рост продаж и количество выпущенных игр на консоль.
# С 2013 по 2015 количество релизов растет, .а доходы продолжают падать.
# И всего за 5 лет с начала старта продаж в 2011 общие доходы составили 4.63 , а доходы в 2015 6.25 мл.
# Можем предположить, что консоль не будет популярна.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Согласен.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Корректированный ввывод.
#
# Огромное количество релизов, доход стремится к нулю. Мертворожденая консоль?
# <div>

# %% [markdown]
# # Xbox One

# %%
#Срез по консоли Xbox One
df_xone=df_curr.query('platform == "xone"')
df_xone.head(5)
# Out:
#                                name platform  year_of_release         genre  \
# 99        call of duty: black ops 3     xone             2015       shooter
# 165              grand theft auto v     xone             2014        action
# 179  call of duty: advanced warfare     xone             2014       shooter
# 242               halo 5: guardians     xone             2015       shooter
# 270                       fallout 4     xone             2015  role-playing
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 99       4.59      2.11      0.01         0.68           NaN         0.0
# 165      2.81      2.19      0.00         0.47          97.0         7.9
# 179      3.22      1.55      0.01         0.48          81.0         5.4
# 242      2.78      1.27      0.03         0.41          84.0         6.4
# 270      2.51      1.32      0.01         0.38          88.0         6.2
#
#     rating  all_region_sales   rating_name
# ...

# %%
#Года продажи игр
df_xone['year_of_release'].unique()
# Out:
# array([2015, 2014, 2013])

# %%
#Сводна таблица доходов и количества релизов
df_xone.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2013                          19            18.96
# 2014                          61            54.07
# 2015                          80            60.14

# %%
#График доходов и количества релизов
df_xone.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum']) \
.plot(grid=True, kind='barh', figsize=(5,3), fontsize=10)
plt.ylabel('Год и Платформа Xbox One')
plt.xlabel('Cумма продаж во всех регионах Xbo One')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Xbo One')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Playstation 4 и Xbox One вышли в один 2013 год, рассмотрим разницу продаж и доходов и сделаем выводы.
# Консоль Xbox One вышла в 2013 году, продажи в первый год составили 19 мл и вышло 19 игр на консоли.
# Релиз похож на Playstation 4 в 2013 году. Вышло 16 игр , а продажи составили 26 мл. Старт у консолей получился примерно одинаковый
#
# В 2014 и 2015 мы видим рост продаж которые составил по годам в 2014 54 мл и в 2015 60 мл. Рост есть, но не большой, аналогичный рост мы имеем у консоли Playstation 4, разница только в том. там больше общие проджа в 2014 году составили 100 мл и в 2015 118 мл.
#
# Количество релизов имеет похожий рост как и на Playstation 4.
#
# Можем с уверенностью сказать, что на консоли Xbox One будет рост в ближайшие 2 года и она будет оставаться актуальной.
# Но доходы и рост продаж в соотношени к Playstation 4 можно ожидать меньше.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Согласен.
#
# </div>

# %% [markdown]
# # Nintendo Wiiu

# %%
#Сделали срез по Nintendo wiiu
df_wiiu=df_curr.query('platform == "wiiu"')
df_wiiu.head(5)
# Out:
#                                     name platform  year_of_release     genre  \
# 110                         mario kart 8     wiiu             2014    racing
# 216  super smash bros. for wii u and 3ds     wiiu             2014  fighting
# 247                             splatoon     wiiu             2015   shooter
# 260                 super mario 3d world     wiiu             2013  platform
# 424                    super mario maker     wiiu             2015  platform
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 110      3.15      2.15      1.28         0.51          88.0         9.1
# 216      2.60      1.08      0.81         0.38           NaN         0.0
# 247      1.54      1.18      1.46         0.26          81.0         8.5
# 260      2.11      1.16      0.73         0.32          93.0         9.0
# 424      1.18      0.89      0.94         0.20          88.0         8.7
#
#     rating  all_region_sales    rating_name
# ...

# %%
#Года когда выходили игры на Wiiu
df_wiiu['year_of_release'].unique()
# Out:
# array([2014, 2015, 2013])

# %%
#Сводная табилица продаж и количества игр на Wiiu
df_wiiu.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum'])
# Out:
#                            count              sum
#                 all_region_sales all_region_sales
# year_of_release
# 2013                          42            21.65
# 2014                          31            22.03
# 2015                          28            16.35

# %%
#График по количеству продаж и релизов на Wiiu
df_wiiu.pivot_table(index='year_of_release', values='all_region_sales',aggfunc=['count','sum']) \
.plot(grid=True, kind='barh', figsize=(7,7), fontsize=10)
plt.ylabel('Год и Платформа Nintendo Wiiu')
plt.xlabel('Cумма продаж во всех регионах Nintendo Wiiu')
# Out:
# Text(0.5, 0, 'Cумма продаж во всех регионах Nintendo Wiiu')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Старт продаж консоли Nintendo Wiiu в 2012 году, вышло 32 игры и сумма продаж составила 17.56 мл.
# В 2013 наблюдаетм рост релизов, который составил 42 игры и небольшой рост доходов, который составил 21.65 мл.
# В 2014 году количество релизов составило 31 как в 2012. доходы составили на уровне 2013 года и составили 22 мл.
# В 2015 уменьшают как доходы так и количество релизов.
#
# Вывод консоль не смогла заинтересовать покупателей и не будет актуальна в 2017 году.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Принято.
#
# </div>

# %% [markdown]
# # Вывод какие платформы падают или растут

# %% [markdown]
# <div class="alert alert-block alert-info">
# Высянили что платформу Playstation 4 и Xbox One имеет рост с 2013 по 2015 год и имеют потенциал роста в будущем.
#
# Платформы Nintendo 3ds, Playstation Vita и Nintendo Wiiu не смогли показать рост продаж и быстро начали терять покупателей.
# Средний срок жизни их примерно составил 5-7 лет.
#
# Прогноз на 2017 год будут актуальны всего 2 платформы Playstation 4 и Xbox One.
# Playstation 4 будет иметь больший рост чем , Xbox One.
#
# Возможно Nintendo в 2017 году выпустит новую консоль. Которая будет успешна как Wii =)
#
# <div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Дополненый вывод
#
# Выяснили что Playstation Vita точно не будет популярна. ее продажи при ее релизах стремятся к нулю.  в 2015 году продади всего на 6.25 мл игр.
#
# Nintendo Wiiu и 3ds будут иметь небольшую но популярность.
#
# <div>

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **[Артём](#results):** ✋ Две топовые платформы действительно хорошо видно. Но важно оставить и те, которые находятся на неплохом уровне продаж, например в данном случае можно оставить от пяти миллионов копий и выше, на твой выбор. Иначе это будет упущенной выгодой для магазина. У этих платформ по-прежнему есть поклонники, и на 2017 год их лучше включить в список.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Выше мы выяснили что потенциально прибыльные платформы это Playstation 4 и Xbox One , по ним и построим ящик с усами
# <div>

# %%
#Сделали срез по xone и ps4
df_pop_pf = df[(df['platform'] == 'xone') | (df['platform'] == 'ps4')]
df_pop_pf.head(5)
# Out:
#                               name platform  year_of_release    genre  \
# 31       call of duty: black ops 3      ps4             2015  shooter
# 42              grand theft auto v      ps4             2014   action
# 77                         fifa 16      ps4             2015   sports
# 87    star wars battlefront (2015)      ps4             2015  shooter
# 92  call of duty: advanced warfare      ps4             2014  shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 31      6.03      5.86      0.36         2.38           NaN         0.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
# 77      1.12      6.12      0.06         1.28          82.0         4.3
# 87      2.99      3.49      0.22         1.28           NaN         0.0
# 92      2.81      3.48      0.14         1.23          83.0         5.7
#
#    rating  all_region_sales    rating_name
# 31    NaN             14.63   нет рейтинга
# ...

# %%
#Сделали продажи до 2 мл
df_sell = df_pop_pf.query('all_region_sales <= 2')

# %%
df_sell.pivot_table(index='platform', values='name', aggfunc='count')
# Out:
#           name
# platform
# ps4        348
# xone       223

# %%
#График с усами по общим продажам на платформе ps4 и xone
df_sell.boxplot(column='all_region_sales', by='platform', figsize=(5, 5))
# Out:
# <AxesSubplot:title={'center':'all_region_sales'}, xlabel='platform'>

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ К сожалению, на этом боксплоте видны только выбросы, и совсем не видны медиана и 75% квантиль. Для более обоснованных выводов нужно сделать дополнительный график, без выбросов.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Переделал
# <div>

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %% [markdown]
# # Вывод по ящику с усами для платформы Xbox One и  Ps4

# %% [markdown]
# <div class="alert alert-block alert-info">
# На ящике с усами для платформ видно, что у нас нет значения минимум, никто не хочешь , чтобы его игра продалась 0 копий и проинесла 0 прибыли.
# Медиана продаж находится около нуля. говорит нам о том, что достаточно много релизов имеют скромные продажи на платформах
# Playstation 4 и Xbox One.
#
# Playstation4
# По третьему квартилю видно,что игры которые выходят на Ps4 стремятся к 1 мл продаж. Выбросы начинаются около 2 мл.
# Можно сделать 3 категории игр, без учета стоимости разработки и рекламы.
# 1. Категория в Медиане игры которые окупились.
# 2. Категория Успешные игры которые приносят прибыль Q3
# 3. Категория Хиты которые продают миллионами копий и приносят огромные доходы, на ящике видно как выбросы.
#
# Xbox One
# По третьему квартилю видно, что игры продают как на Playstation 4, но немного меньше. и выбросы начинают немного раньше чем 2 мл копий.
# Максимальный выброс на Playstation 4 находится в районе 14.5 мл копий, а на xbox стремится к 8 мл копий.
#
# Вывод Playstation 4 и Xbox One продают игры которые входят в медиану и третий квартиль одинаково, но на Playstation 4 есть игры которые могут продаваться большими копиями чем на Xbox One.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Дополненый вывод по перестроенному boxplot
#
# Медиана на Xbox One немного больше чем на Playstation4, 75% релизов на Xbox one продаются в районе 500 тысяч копий.
#
# На Playstastion4 400-450 тысяч копий.
#
# Выбросы на Playstation 4 начинаются от 1 мл, а на Xbox One с 1.25 мл.
#
# Создается впечатление, что Xbox one популрянее и продает больше.
#
# Но из-за большого количества релизов на Playstation 4  348 шт, а на Xbox One всего 223 шт. Создается искажение восприятие.
#
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %%
# Сделали критик скор и юзер скор от 0 до 100 оценку, у юзер скор было от 0 до 10 
df['user_score'] = df['user_score']*10
df['user_score']
# Out:
# 0        80.0
# 1         0.0
# 2        83.0
# 3        80.0
# 4         0.0
#          ...
# 16710     0.0
# 16711     0.0
# 16712     0.0
# 16713     0.0
# 16714     0.0
# Name: user_score, Length: 16444, dtype: float64

# %%
#Срез по Playstation4
df_sc = df.query('platform == "ps4"')
df_sc
# Out:
#                                  name platform  year_of_release         genre  \
# 31          call of duty: black ops 3      ps4             2015       shooter
# 42                 grand theft auto v      ps4             2014        action
# 77                            fifa 16      ps4             2015        sports
# 87       star wars battlefront (2015)      ps4             2015       shooter
# 92     call of duty: advanced warfare      ps4             2014       shooter
# ...                               ...      ...              ...           ...
# 16500                     root letter      ps4             2016     adventure
# 16503               shin hayarigami 2      ps4             2016     adventure
# 16526                      dungeons 2      ps4             2016  role-playing
# 16530         carmageddon: max damage      ps4             2016        action
# 16585   farming 2017 - the simulation      ps4             2016    simulation
#
# ...

# %%
#График оценок критиков и количество продаж по всем регионам с низкими оценками 
df_sc.pivot_table(index=['all_region_sales','name'], values='critic_score').head(10).sort_values(by='critic_score') \
.plot(grid=True, kind='barh', figsize=(5,5), fontsize=7)
plt.ylabel('Количество проданных копий игр')
plt.xlabel('Оценка критиков')
# Out:
# Text(0.5, 0, 'Оценка критиков')

# %%
#График оценок пользователей и количество продаж по всем регионам с низкими оценками
df_sc.pivot_table(index=['all_region_sales','name'], values='user_score').head(10).sort_values(by='user_score') \
.plot(grid=True, kind='barh', figsize=(5,5), fontsize=7)
plt.ylabel('Количество проданных копий игр')
plt.xlabel('Оценка Пользователей')
# Out:
# Text(0.5, 0, 'Оценка Пользователей')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Построили два графика количество продаж по оценкам критиков и пользователей. Рассмотрим сначало релизы которые имеют не большие продажи порядка 10-20 тысяч копий на платформе Playstation 4.
# У пользователей у части проектов отсутсвует оценка.
#
# Рассмотрим проекты которые пересекаются в наших таблицах.
# Игра Подземелье 2 оценена критиками на 60 баллов. и имеет продажи порядка 10 тысяч копий. Пользователи же оценили данную игру на 80 баллов. Это большая разница в оценке игры. пользователям она понравилась больше чем критикам, если пользователи ориентируются на оценки критиков. то скорее всего они эту игры пропустят. Можем предположить, что игра понравилась тем кто играл в первую часть. Назовем таких пользователей фанатами. Фанаты ставят игре более высокие оценки, но они не могут повлиять на продажу данной игры.
#
# Кармагедон макс дамаг - продажи 10тыс копий, оценена критиками на 50 баллов, а пользователями на 5.5 - тут мы видим что пользователи и критики согласны что игра заслужила эту оценку.
#
# Прототип: зараженный комплект - продажи 10 тысчяч копий данная игра оценена критикам  на 47 баллов, пользователи оценили всего на 20 баллов.
#
# Можем сделать вывод, что критики влияют на продажи игр. Пользователи могут оценивать проекты выше, чем критики, но влияние они не оказывают на продажи.
#
# <div>

# %%
#График оценок критиков и количество продаж по всем регионам с высокими оценками
df_sc.pivot_table(index=['all_region_sales','name'], values='critic_score').tail(10).sort_values(by='critic_score') \
.plot(grid=True, kind='barh', figsize=(5,5), fontsize=7)
plt.ylabel('Количество проданных копий игр')
plt.xlabel('Оценка критиков')
# Out:
# Text(0.5, 0, 'Оценка критиков')

# %%
#График оценок пользователей и количество продаж по всем регионам с высокими оценками
df_sc.pivot_table(index=['all_region_sales','name'], values='user_score').tail(10).sort_values(by='user_score') \
.plot(grid=True, kind='barh', figsize=(5,5), fontsize=7)
plt.ylabel('Количество проданных копий игр')
plt.xlabel('Оценка Пользователей')
# Out:
# Text(0.5, 0, 'Оценка Пользователей')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Рассмотрим график на котором игры которые имебт продажи от 5 мл до 12 мл  копий.
#
# Гта5 оценена критиками в 95 баллов и имеет продажи 12.62 мл копий. Это самый крупный релиз на Playsstation 4.
# Пользователи оценили игру на 85 баллов.
#
# Фоллаут 4 - критики оценили на 85 баллов, данная игра продалась 7.17 мл копий. Пользователи оценили данную игру на 65 баллов.
# Пользовательская оценка низкая, такую оценку критики ставят проектам которые имеют продажи в 10 тысяч копий.
# В данном случаем нам отлично видно, влияние оценки критиков на продажу игры в отличии от пользователей.
#
# Также на графике есть два релизы серия игр Call of duty, игры разные, но серия одна критики оценили игру на 75 баллов, а пользователи на 57 баллов.
#
# Можно сделать вывод. Есть серии игр, которые могут продавать огромными тиражами не смотря на не самые выские оценки критиков и более низкие оценки пользователй.
# <div>

# %% [markdown]
# # Общий вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
# Изучив графики мы выяснили, то критики влияют на продажи больше, чем пользователи.
#
# Также нам стало известно, что есть популярные серии игр, например Call oF Duty, Fifa - разница в оценки между пользователями и критками может быть около 20%, видно зависимость.Пользователи ориентируются на оценки критиков, они выше чем пользователей. Пользователи покупают популярную серию игр, но ставят в итоге более низкую оценку.
#
# Влияние критиков возрастает, если игры это малоизвестные проекты.
#
# <div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Примечание, кажется я не совсем верно понял, что надо сделать. и получилась двойная работа :) но я ее оставлю.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Я тоже удивился, в ТЗ все четко расписано. Но молодец, провел дописследование, так что можно только похвалить.
#
# </div>

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах.

# %%
#График рассеиваня всех продаж, в отношении критиков.
df_sc.plot.scatter(x='all_region_sales', y='critic_score', c='DarkBlue')
plt.xlabel('Количество проданных копий игр')
plt.ylabel('Оценка Критиков')
# Out:
# Text(0, 0.5, 'Оценка Критиков')

# %% [markdown]
# <div class="alert alert-block alert-info">
# На графике рассеивания общих продаж к оценке критиков видно зависимость, оценка стремится выше 65 баллов, а продажи стремятся к 2 мл копий.
# Даже есть успешные проекты с продажами около 2 мл с оценками в диапазоне от 55 до 70.
# На графике видно очень много проектов оценено выше 75 баллов но продажи около 500 тысяч копий.
#
# <div

# %%
#График рассеиваня всех продаж, в отношении пользователей.
df_sc.plot.scatter(x='all_region_sales', y='user_score', c='DarkBlue')
plt.xlabel('Количество проданных копий игр')
plt.ylabel('Оценка Пользователи')
# Out:
# Text(0, 0.5, 'Оценка Пользователи')

# %% [markdown]
# <div class="alert alert-block alert-info">
# График похож на оценки критиков, но пользователи оценивают часть крупных проекто с большими продажи 4мл-10мл ниже чем критики. Но это не влият на продажи.
#
# Также у нас есть значения 0. Мы выше решили, что пользователи могут оценивать релизы в любое время, в отличии от критиков. Но их заинтересованность в оценке может стремится к 0. Нам отлично это видно на крупных проектах. Когда продажи у игры 8 мл, а пользователи не оценили данную игру.
# <div>

# %%
#График по всем платформа продажи на основе критиков
df.plot.scatter(x='all_region_sales', y='critic_score', c='DarkBlue')
plt.xlabel('Количество проданных копий игр')
plt.ylabel('Оценка Пользователей')
# Out:
# Text(0, 0.5, 'Оценка Пользователей')

# %%
#График по всем платформа продажи на основе пользователей
df.plot.scatter(x='all_region_sales', y='user_score', c='DarkBlue')
plt.xlabel('Количество проданных копий игр')
plt.ylabel('Оценка Пользователей')
# Out:
# Text(0, 0.5, 'Оценка Пользователей')

# %% [markdown]
# <div class="alert alert-block alert-info">
# На графиках рассеивания видно, соотношение что на плаформе Playstation 4, что сразу на всех платформах примерно одинаково.
# Существуют релизы с невысокими оценками,но большими продажами.
# <div>

# %% [markdown]
# # Общий вывод по графикам Рассеивания

# %% [markdown]
# <div class="alert alert-block alert-info">
# Оценки критиков имеют больше влияние чем пользовательские оценки.
#
# Оценки критиков имеют диапазон от 40 до 90 баллов , в нем оценен большое количество игр.
#
# У пользователей данный диапозон составляет около 55-90 баллов
#
# Пользователи могут вообще не ставить оценки, но могут их ставят позже.
# Критки оценивают чаще на старте продаж. Но не оценивают проекты спустя время.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %%
#Кореляция сумма всех продаж, оценки критиков и пользователей Playstation4
corr= df_sc[['all_region_sales',\
           'user_score',\
           'critic_score',\
           ]].corr()
corr.round(decimals=3).style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_b1065_row0_col0, #T_b1065_row1_col1, #T_b1065_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b1065_row0_col1, #T_b1065_row0_col2, #T_b1065_row1_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b1065_row1_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_b1065_row2_col0 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_b1065_row2_col1 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# </style>
# <table id="T_b1065">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1065_level0_col0" class="col_heading level0 col0" >all_region_sales</th>
#       <th id="T_b1065_level0_col1" class="col_heading level0 col1" >user_score</th>
#       <th id="T_b1065_level0_col2" class="col_heading level0 col2" >critic_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# # Вывод Корреляция

# %% [markdown]
# <div class="alert alert-block alert-info">
# Корреляция между общими продажами и оценками пользователей почти нет, между критиками и общими продажами больше, но как
# мы установили выше. Критики влияют, но иногда больше влият сама серия игр на свои продажи.
# <div>

# %% [markdown]
# <div class="alert alert-info">
#
# **[Артём](#results):** ✍️ Если корреляция меньше 0.25 то можно смело утверждать, что ее нет. Если меньше 0.5 - слабо выраженная.
#
# </div>

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
#Сводная таблица популярности жанров за все время 
df.groupby('genre').agg({'all_region_sales' :'mean'}) \
.sort_values(by='all_region_sales',ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
#Сводная таблица популярности с 2011 по 2015 год
df_curr.groupby('genre').agg({'all_region_sales' :'mean'}) \
.sort_values(by='all_region_sales',ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='genre'>

# %% [markdown]
# # Вывод

# %% [markdown]
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# <div class="alert alert-block alert-info">
# Сделали две сводные таблицы c графиками за все время и с 2011 до 2015- назовем это Актуальными жанрами.
# с 1980 по 2016 год топ 3 список жанров это платформеры, шутеры и рпг.
# с 2011 до 2015 года топ 3 список жанров шутеры, плаформеры и спортивные игры.
# Марио на века!?:)
#
# Можно сказать что платформеры были популярны и осталим такими. жанр прошел проверку времени.
# Шутеры стали более популярны, А рпг заняли 4 срочку, на 3 поднялись спортивные игры.
#
# Топ 3 прибыльных актуальных жанра в них нужно иметь хорошую реакцию.
#
# топ 3 жанрами с низкими продажами.
# с 1980 по 2016 год это пазлы, стратегии, приключения.
# с 2011 по 2015 год ничего не  менятся,немного порядок, списко тотже стратегии, пазлы и приключения
# Топ 3 жанра не прибыльных нужно больше подумать.
#
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Отлично.
#
# ![](https://avatars.mds.yandex.net/get-pdb/1209663/83aef093-8459-483e-adcd-217336d0bcce/s1200?webp=false)
#
# </div>

# %% [markdown]
# ## Шаг 4. Составьте портрет пользователя каждого региона

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ По условиям брифа «Не учитывайте в работе данные за предыдущие годы». Измени период.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Раз мы строим вариант развития на 2017 год, возмем значит с 2013 по 2017 года срез и построим все последущие иследования на нем.
# <div>

# %% [markdown]
# ### Определите для пользователя каждого региона (NA, EU, JP):

# %% [markdown]
# ### Самые популярные платформы (топ-5). Опишите различия в долях продаж.

# %%
#Самые попопудярные платформы в долях продаж США
df_curr.pivot_table(index='platform', values='na_sales',aggfunc='mean') \
.sort_values(by='na_sales',ascending=False).head(5) \
.plot(kind='barh')
plt.xlabel('Доля продаж')
plt.ylabel('Платформы')
# Out:
# Text(0, 0.5, 'Платформы')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Консоли Японцев в стране гайдзинов не популярны! Майкрософт выиграла войну за свою страну и своих клиентов!
# <div>

# %%
#Самые попопудярные платформы в долях продаж Европа
df_curr.pivot_table(index='platform', values='eu_sales',aggfunc='mean') \
.sort_values(by='eu_sales',ascending=False).head(5) \
.plot(kind='barh')
plt.xlabel('Доля продаж')
plt.ylabel('Платформы')
# Out:
# Text(0, 0.5, 'Платформы')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Европа очень любит консоли Сони, и в равной степени предпочитает консоли от Nintendo и  Microsoft
# <div>

# %%
#Самые попопудярные платформы в долях продаж Япония
df_curr.pivot_table(index='platform', values='jp_sales',aggfunc='mean') \
.sort_values(by='jp_sales',ascending=False).head(5) \
.plot(kind='barh')
plt.xlabel('Доля продаж')
plt.ylabel('Платформы')
# Out:
# Text(0, 0.5, 'Платформы')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Портативный гейминг топ 1? В Америке и Европе о таком даже не слышали.
# <div>

# %% [markdown]
# ### Самые популярные жанры (топ-5). Поясните разницу.

# %%
df_curr.pivot_table(index='genre', values='na_sales',aggfunc='mean') \
.sort_values(by='na_sales',ascending=False).head(5) \
.plot(kind='barh')
plt.xlabel('Доля продаж')
plt.ylabel('Платформы')
# Out:
# Text(0, 0.5, 'Платформы')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Геймеры Сша очень любят шутеры и спорт игры.
# Чуть меньшьше играют в платформеры, музыкальные и файтинги.
# <div>

# %%
df_curr.pivot_table(index='genre', values='eu_sales',aggfunc='mean') \
.sort_values(by='eu_sales',ascending=False).head(5) \
.plot(kind='barh')
plt.xlabel('Доля продаж')
plt.ylabel('Платформы')
# Out:
# Text(0, 0.5, 'Платформы')

# %% [markdown]
# <div class="alert alert-block alert-info">
# Популряность жанров в Европе очень похожа на Сша, но на втором месте гонки, видимо в европе ждут новый Gran Turismo.
# Также популярен жанр спорт, правда в Сша это Madden Nfl, в европе это Fifa.
# <div>

# %%
df_curr.pivot_table(index='genre', values='jp_sales',aggfunc='mean') \
.sort_values(by='jp_sales',ascending=False).head(5) \
.plot(kind='barh')
plt.xlabel('Доля продаж')
plt.ylabel('Платформы')
# Out:
# Text(0, 0.5, 'Платформы')

# %% [markdown]
# <div class="alert alert-block alert-info">
# В Японии популярны тоже платформе, но баллом правят рпг. Финал Фентези, Драгон Болл и другие.
# Также как и в Сша есть популярный жанр файтинг.
# <div>

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# <div class="alert alert-block alert-info">
# Рейтинговая компания  ESRB  оценивает игры только в Сша, значит будет рассматривать регион Сша.
# <div>

# %%
#Сводный график рейтингов и продаж в Сша
df.pivot_table(index = 'rating_name', values='na_sales').sort_values(by='na_sales').plot(kind='barh')
plt.xlabel('Доля продаж')
plt.ylabel('Рейтинг')
# Out:
# Text(0, 0.5, 'Рейтинг')

# %% [markdown]
# # Общий вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Портрет пользоватля NA - консоли от Microsoft заняли рынок очень мощно, консоли японцев отошли на второй план.
# В Сша популярен жанр игр Шутеры , также спорт, платформеры.
# Также  в топ 5 входят жанры гонки, спорт и файтинги.
# Рейтинг ESRB не влияет на регион Сша. Игры с рейтингом от 17 и только для взрослых продаются лучше, чем игры с другими рейтингами.
#
# Портрет пользоватля EU - чаще выбирает консоль от японского бренда. Самый популярный жанр шутеры.
# Оставшиеся популярные жанры похожи на Сша. Файтинги не пользуются популярностью в европе, а популярны гонки.
#
# Портрет пользоватля JP - тотальное преимущество у японских производителей консолей, скорее даже портативное преимущество
# Самая популярная консоль Nintendo 3ds. Жанровое разнообразие тоже имеет сильное отличие от регионов NA и EU.
# Топ 1 жанр Рпг. оставшиеся жанры в Топ 5 это платформер,файтинг, пазл и симуляторы.
#
#
# Часть жанров Сша и Японии пересекаются, но файтинг в Сша это Мортал Комбат, а в японии это СтритФайтер/Текен и другие.
# Если высоздаете игру для рынка Сша но ее можно успешно продать и в Европе. Рынок Японии особенный, но своими вкусами.
# Симуляторами свидания например :)
# <div>

# %% [markdown]
# ## 📊 Шаг 5. Проверьте гипотезы
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# <div class="alert alert-danger">
#
# #### **Артём:** ✋ По условиям брифа «Не учитывайте в работе данные за предыдущие годы». Измени период.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Критерии проверки
# Проверка гипотезы о равенстве среднего двух генеральных совокупностей по взятым из них выборкам
# <div>

# %% [markdown]
# ### 📊 Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;

# %% [markdown]
# # 1 Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# <div class="alert alert-block alert-info">
# Также берем акутальный период 2013-2015 года
# <div>

# %% [markdown]
# H0: средний пользовательский рейтинг платформ Xbox и PC одинаковый
#
# H1: средний пользовательский рейтинг жанров Xbox и PC различается

# %%
# Cоздаем две генеральные совокупности по условию задачи
xone = df_curr[(df_curr['platform'] == 'xone') & (df_curr['user_score'] > 0)]['user_score']
pc = df_curr[(df_curr['platform'] == 'pc') & (df_curr['user_score'] > 0)]['user_score']

# %%
alpha = 0.05
results = st.ttest_ind(xone, pc, equal_var = False)
print('p-значение: ', results.pvalue)

if results.pvalue < alpha: 
    print('Отвергаем нулевую гипотезу ')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение:  0.2867036680187632
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# # Вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
# Cредний пользовательский рейтинг жанров Xbox и PC одинаковый
# <div>

# %% [markdown]
# ### 📊 Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# # Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# H0: средний пользовательский рейтинг жанров Action и Sports разные
#
# H1: средний пользовательский рейтинг жанров Action и Sports одинаковые

# %%
# Cоздаем две генеральные совокупности по условию задачи
action = df_curr[(df_curr['genre'] == 'action') & (df_curr['user_score'] > 0)]['user_score']
sports = df_curr[(df_curr['genre'] == 'sports') & (df_curr['user_score'] > 0)]['user_score']

# %%
alpha = 0.05
results = st.ttest_ind(action, sports, equal_var = False)
print('p-значение: ', results.pvalue)

if results.pvalue < alpha: 
    print('Отвергаем нулевую гипотезу ')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение:  3.5076737062533423e-19
# Отвергаем нулевую гипотезу

# %% [markdown]
# # Вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
# Средний пользовательский рейтинг жанров Action и Sports одинаковый
# <div>

# %% [markdown]
# # Шаг 6

# %% [markdown]
# # Общий вывод

# %% [markdown]
# <div class="alert alert-block alert-info">
# Провелил исследование, увидели развитие игровой индустрии с 1980 по 2016 год.
# К 2016 год индустрия начала терять темп. Я бы назвал это коррекцией рынка.
# Узнали что к 2017 году останется всего 2 популярные платформы Playstation 4 и Xbox One, которые смогут показать рост показателей прибыли и количество выходящих игр на них. Будем ждать новых игроков в 2017 году на рынке.
# Построили портртер Пользователей NA. EU и JP - как и следовала ожидать рынок японии и вкусы японских геймеров уникальные в отличии от NA и EU.
#
# Проверили две гипотезы Оценки между платформами Xbox One и PС - гипотезу отвергли.
#
# Вторая гипотеза Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные. - гипотеза подтвердилась.
#
#
# <div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# По поводу нашего магазина. Мы можем закупать игры на Wiiu и 3ds. PSV - к сожалению сдулась уже.
# Закуп игр на 3ds можно ориетировать больше на японский рынок. Мы увидели тотальную доминацию там.
# Рынок европы  популярность Playstation 4, рынок Сша Xbox One. - Жанровые предпочтения у рынков похожи.
# Формировать список игр для японии надо внимательно с учетом их жанровых пристрастий.
#
# Нужно внимательно следить за релизами на Playstation 4 - самая популярная плафторма. несколько драйверов в 2017 и последущие годы. могу нас озолотить! Даже на рынке Сша!
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хороший вывод.
#
# </div>
# <div class="alert alert-warning">
#
# **Артём:** 👉 Не забудь его скорректировать с учетом новых данных.
# </div>

# %% [markdown]
# ## 🏁 Итоги ревью
# <a id="results"></a>
# [В начало](#start)
#
# <div class="alert alert-danger">
#
# ✋ Итерация №1
#
# Александр, спасибо за работу. Осталось исправить несколько комментариев и можно идти к заказчику. Молодец! 👍
#
# Для удобства, комментарии которые нужно скорректировать я добавил в меню **Contents** слева.
#
# Жду новую версию проекта. 🙂
#
# </div>
